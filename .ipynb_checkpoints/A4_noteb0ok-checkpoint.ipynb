# %%
import pandas as pd
data = pd.read_csv("assignment_4_files/BingLiu.csv",delimiter='\t',header=None)
data.columns=["word","polarity"]
data
# Out:
#            word  polarity
# 0            a+  positive
# 1        abound  positive
# 2       abounds  positive
# 3     abundance  positive
# 4      abundant  positive
# ...         ...       ...
# 6784       zaps  negative
# 6785     zealot  negative
# 6786    zealous  negative
# 6787  zealously  negative
# 6788     zombie  negative
#
# [6789 rows x 2 columns]

# %%
dictionary = pd.read_csv("assignment_4_files/english-hindi-dictionary.txt",sep="\|\|\|",header=None)
dictionary.columns = ["english","hindi"]
dictionary
# Out:
# /home/venktesh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#                  english             hindi
# 0                   the                  द
# 1                     .                  ।
# 2                     ,                  ,
# 3                     i                मैं
# 4                    to        करने के लिए
# ...                  ...               ...
# 142746            zx-5n              zx-5n
# 142747          zx-6000            zx-6000
# 142748           zx5000             zx5000
# 142749  zzzzzzzzzzzzzzz    zzzzzzzzzzzzzzz
# 142750            <unk>              <unk>
#
# [142751 rows x 2 columns]

# %%
dictionary["english"] = dictionary["english"].apply(lambda x: x.strip())
dictionary["hindi"] = dictionary["hindi"].apply(lambda x: str(x).strip())

dictionary[dictionary["english"]=="and"]
# Out:
#   english hindi
# 5     and    और

# %%
dictionary[dictionary["english"]=="abundant"]
# Out:
#         english  hindi
# 15348  abundant  हुस्न

# %%
dictionary["hindi"].values
# Out:
# array(['द', '।', ',', ..., 'zx5000', 'zzzzzzzzzzzzzzz', '<unk>'],
#       dtype=object)

# %%
list(dictionary['english'].values).index("the")
# Out:
# 0

# %%
new_biling_dict = {'english':[],'hindi':[],'polarity':[]}
english_list = list(dictionary['english'].values)
hindi_list = list(dictionary['hindi'].values)
for index,row in data.iterrows():
    if row['word'] in english_list and row['word'] not in new_biling_dict['english']:
        new_biling_dict['english'].append(row['word'])
        new_biling_dict['hindi'].append(hindi_list[english_list.index(row['word'])])
        new_biling_dict['polarity'].append(row['polarity'])
        
new_biling_dict
# Out:
# {'english': ['abound',
#   'abounds',
#   'abundance',
#   'abundant',
#   'accessable',
#   'accessible',
#   'acclaim',
#   'acclaimed',
#   'accolade',
#   'accolades',
#   'accomplish',
#   'accomplished',
#   'accomplishment',
#   'accomplishments',
#   'accurate',
#   'accurately',
#   'achievable',
#   'achievement',
#   'achievements',
#   'acumen',
#   'adaptable',
#   'adaptive',
#   'adequate',
#   'adjustable',
#   'admirable',
#   'admirably',
#   'admiration',
#   'admire',
#   'admirer',
#   'admiring',
#   'adorable',
#   'adore',
#   'adored',
#   'adulation',
#   'advanced',
#   'advantage',
#   'advantageous',
#   'advantages',
#   'adventuresome',
#   'adventurous',
#   'advocate',
#   'advocated',
#   'advocates',
#   'affection',
#   'affectionate',
#   'affinity',
#   'affirm',
#   'affirmation',
#   'affirmative',
#   'affluence',
#   'affluent',
#   'afford',
#   'affordable',
#   'affordably',
#   'afordable',
#   'agile',
#   'agility',
#   'agreeable',
#   'agreeably',
#   'all-around',
#   'alluring',
#   'altruistic',
#   'amaze',
#   'amazed',
#   'amazement',
#   'amazes',
#   'amazing',
#   'amazingly',
#   'ambitious',
#   'ameliorate',
#   'amenable',
#   'amicable',
#   'amity',
#   'ample',
#   'amply',
#   'amuse',
#   'amusing',
#   'amusingly',
#   'angel',
#   'angelic',
#   'apotheosis',
#   'appeal',
#   'appealing',
#   'applaud',
#   'appreciable',
#   'appreciate',
#   'appreciated',
#   'appreciates',
#   'appreciative',
#   'appropriate',
#   'approval',
#   'approve',
#   'ardent',
#   'articulate',
#   'aspiration',
#   'aspirations',
#   'aspire',
#   'assurance',
#   'assurances',
#   'assure',
#   'assuredly',
#   'assuring',
#   'astonish',
#   'astonished',
#   'astonishing',
#   'astonishingly',
#   'astonishment',
#   'astound',
#   'astounded',
#   'astounding',
#   'astoundingly',
#   'attentive',
#   'attraction',
#   'attractive',
#   'attractively',
#   'audible',
#   'audibly',
#   'auspicious',
#   'authentic',
#   'authoritative',
#   'autonomous',
#   'available',
#   'aver',
#   'avid',
#   'avidly',
#   'award',
#   'awarded',
#   'awards',
#   'awe',
#   'awed',
#   'awesome',
#   'awesomely',
#   'awesomeness',
#   'awestruck',
#   'awsome',
#   'backbone',
#   'balanced',
#   'bargain',
#   'beautiful',
#   'beautifully',
#   'beautify',
#   'beauty',
#   'believable',
#   'beloved',
#   'benefactor',
#   'beneficial',
#   'beneficiary',
#   'benefit',
#   'benefits',
#   'benevolence',
#   'benevolent',
#   'benifits',
#   'best',
#   'best-known',
#   'best-performing',
#   'best-selling',
#   'better',
#   'better-known',
#   'better-than-expected',
#   'beutifully',
#   'blameless',
#   'bless',
#   'blessing',
#   'bliss',
#   'blissful',
#   'blissfully',
#   'blockbuster',
#   'bloom',
#   'blossom',
#   'bolster',
#   'bonus',
#   'bonuses',
#   'boom',
#   'booming',
#   'boost',
#   'boundless',
#   'bountiful',
#   'brainy',
#   'brand-new',
#   'brave',
#   'bravery',
#   'bravo',
#   'breakthrough',
#   'breakthroughs',
#   'breathlessness',
#   'breathtaking',
#   'breathtakingly',
#   'breeze',
#   'bright',
#   'brighten',
#   'brighter',
#   'brightest',
#   'brilliance',
#   'brilliant',
#   'brilliantly',
#   'brisk',
#   'brotherly',
#   'buoyant',
#   'cajole',
#   'calm',
#   'calming',
#   'capability',
#   'capable',
#   'capably',
#   'captivate',
#   'captivating',
#   'carefree',
#   'cashback',
#   'catchy',
#   'celebrate',
#   'celebrated',
#   'celebration',
#   'champ',
#   'champion',
#   'charisma',
#   'charismatic',
#   'charitable',
#   'charm',
#   'charming',
#   'charmingly',
#   'cheaper',
#   'cheapest',
#   'cheer',
#   'cheerful',
#   'cheery',
#   'cherish',
#   'cherished',
#   'chic',
#   'clarity',
#   'classic',
#   'classy',
#   'clean',
#   'cleaner',
#   'cleanest',
#   'cleanliness',
#   'cleanly',
#   'clear',
#   'clear-cut',
#   'cleared',
#   'clearer',
#   'clearly',
#   'clears',
#   'clever',
#   'cleverly',
#   'coherence',
#   'coherent',
#   'cohesive',
#   'colorful',
#   'comfort',
#   'comfortable',
#   'comfortably',
#   'comforting',
#   'comfy',
#   'commend',
#   'commendable',
#   'commendably',
#   'commitment',
#   'commodious',
#   'compact',
#   'compactly',
#   'compassion',
#   'compassionate',
#   'compatible',
#   'competitive',
#   'complement',
#   'complementary',
#   'complemented',
#   'complements',
#   'compliant',
#   'compliment',
#   'complimentary',
#   'comprehensive',
#   'conciliatory',
#   'concise',
#   'confidence',
#   'confident',
#   'congenial',
#   'congratulate',
#   'congratulation',
#   'congratulations',
#   'conscientious',
#   'considerate',
#   'consistent',
#   'consistently',
#   'constructive',
#   'consummate',
#   'contentment',
#   'continuity',
#   'contrasty',
#   'contribution',
#   'convenience',
#   'convenient',
#   'conveniently',
#   'convience',
#   'convienient',
#   'convient',
#   'convincing',
#   'convincingly',
#   'cool',
#   'coolest',
#   'cooperative',
#   'cornerstone',
#   'correct',
#   'correctly',
#   'cost-effective',
#   'cost-saving',
#   'courage',
#   'courageous',
#   'courteous',
#   'covenant',
#   'cozy',
#   'creative',
#   'credence',
#   'credible',
#   'crisp',
#   'crisper',
#   'cure',
#   'cure-all',
#   'cushy',
#   'cute',
#   'cuteness',
#   'daring',
#   'darling',
#   'dashing',
#   'dawn',
#   'dazzle',
#   'dazzled',
#   'dazzling',
#   'dead-on',
#   'decency',
#   'decent',
#   'decisive',
#   'dedicated',
#   'defeat',
#   'defeated',
#   'defeating',
#   'defeats',
#   'defender',
#   'deference',
#   'deft',
#   'delectable',
#   'delicacy',
#   'delicate',
#   'delicious',
#   'delight',
#   'delighted',
#   'delightful',
#   'delightfully',
#   'dependable',
#   'dependably',
#   'deservedly',
#   'deserving',
#   'desirable',
#   'desiring',
#   'destiny',
#   'detachable',
#   'devout',
#   'dexterous',
#   'dextrous',
#   'dignified',
#   'dignity',
#   'diligence',
#   'diligent',
#   'diligently',
#   'diplomatic',
#   'dirt-cheap',
#   'distinction',
#   'distinctive',
#   'distinguished',
#   'diversified',
#   'divine',
#   'dominate',
#   'dominated',
#   'dominates',
#   'doubtless',
#   'dreamland',
#   'dumbfounded',
#   'dummy-proof',
#   'durable',
#   'dynamic',
#   'eager',
#   'eagerly',
#   'eagerness',
#   'earnest',
#   'earnestly',
#   'ease',
#   'eased',
#   'eases',
#   'easier',
#   'easiest',
#   'easiness',
#   'easing',
#   'easy',
#   'easy-to-use',
#   'easygoing',
#   'ebullience',
#   'economical',
#   'ecstasy',
#   'ecstatic',
#   'ecstatically',
#   'educated',
#   'effective',
#   'effectively',
#   'effectiveness',
#   'efficient',
#   'efficiently',
#   'effortless',
#   'effortlessly',
#   'effusion',
#   'effusive',
#   'elan',
#   'elated',
#   'elation',
#   'elegance',
#   'elegant',
#   'elegantly',
#   'elevate',
#   'elite',
#   'eloquence',
#   'eloquent',
#   'eloquently',
#   'eminence',
#   'eminent',
#   'empathize',
#   'empathy',
#   'empower',
#   'empowerment',
#   'enchanted',
#   'enchanting',
#   'encourage',
#   'encouragement',
#   'encouraging',
#   'endear',
#   'endearing',
#   'endorse',
#   'endorsed',
#   'endorsement',
#   'endorses',
#   'endorsing',
#   'energetic',
#   'energize',
#   'energy-efficient',
#   'energy-saving',
#   'engaging',
#   'engrossing',
#   'enhance',
#   'enhanced',
#   'enhancement',
#   'enhances',
#   'enjoy',
#   'enjoyable',
#   'enjoyably',
#   'enjoyed',
#   'enjoying',
#   'enjoyment',
#   'enjoys',
#   'enlighten',
#   'enlightenment',
#   'enough',
#   'enraptured',
#   'enrich',
#   'enrichment',
#   'enterprising',
#   'entertain',
#   'entertaining',
#   'entertains',
#   'enthralled',
#   'enthusiasm',
#   'enthusiast',
#   'enthusiastic',
#   'enthusiastically',
#   'entice',
#   'enticed',
#   'enticing',
#   'entranced',
#   'entrancing',
#   'entrust',
#   'enviable',
#   'envious',
#   'enviously',
#   'envy',
#   'equitable',
#   'ergonomical',
#   'ethical',
#   'euphoria',
#   'euphoric',
#   'evaluative',
#   'evenly',
#   'eventful',
#   'everlasting',
#   'evocative',
#   'exceed',
#   'exceeded',
#   'exceeding',
#   'exceedingly',
#   'exceeds',
#   'excel',
#   'excelent',
#   'excellant',
#   'excelled',
#   'excellence',
#   'excellency',
#   'excellent',
#   'excellently',
#   'excels',
#   'exceptional',
#   'exceptionally',
#   'excite',
#   'excited',
#   'excitedly',
#   'excitement',
#   'excites',
#   'exciting',
#   'exellent',
#   'exemplary',
#   'exhilarating',
#   'exhilaration',
#   'expansive',
#   'expeditiously',
#   'expertly',
#   'exquisite',
#   'exquisitely',
#   'extol',
#   'extoll',
#   'extraordinarily',
#   'extraordinary',
#   'exuberant',
#   'eye-catching',
#   'eyecatching',
#   'fabulous',
#   'fabulously',
#   'facilitate',
#   'fair',
#   'fairly',
#   'fairness',
#   'faith',
#   'faithful',
#   'faithfully',
#   'faithfulness',
#   'fame',
#   'famed',
#   'famous',
#   'famously',
#   'fancier',
#   'fancy',
#   'fanfare',
#   'fans',
#   'fantastic',
#   'fantastically',
#   'fascinate',
#   'fascinating',
#   'fascination',
#   'fashionable',
#   'fashionably',
#   'fast',
#   'fast-paced',
#   'faster',
#   'fastest',
#   'faultless',
#   'fav',
#   'fave',
#   'favor',
#   'favorable',
#   'favored',
#   'favorite',
#   'favour',
#   'fearless',
#   'feasible',
#   'feasibly',
#   'feat',
#   'feature-rich',
#   'feisty',
#   'fertile',
#   'fervent',
#   'fervently',
#   'fervor',
#   'festive',
#   'fidelity',
#   'fiery',
#   'fine',
#   'finely',
#   'finer',
#   'finest',
#   'firmer',
#   'first-class',
#   'first-rate',
#   'flashy',
#   'flatter',
#   'flattering',
#   'flawless',
#   'flawlessly',
#   'flexibility',
#   'flexible',
#   'flourish',
#   'flourishing',
#   'fluent',
#   'flutter',
#   'fond',
#   'fondly',
#   'fondness',
#   'foolproof',
#   'foremost',
#   'foresight',
#   'formidable',
#   'fortitude',
#   'fortuitous',
#   'fortuitously',
#   'fortunate',
#   'fortunately',
#   'fortune',
#   'free',
#   'freed',
#   'freedom',
#   'freedoms',
#   'fresh',
#   'fresher',
#   'freshest',
#   'friendliness',
#   'friendly',
#   'frolic',
#   'frugal',
#   'fruitful',
#   'ftw',
#   'fulfillment',
#   'fun',
#   'futuristic',
#   'gaiety',
#   'gain',
#   'gained',
#   'gaining',
#   'gains',
#   'gallant',
#   'galore',
#   'geeky',
#   'gem',
#   'gems',
#   'generosity',
#   'generous',
#   'generously',
#   'genial',
#   'genius',
#   'gentle',
#   'gentlest',
#   'genuine',
#   'gifted',
#   'glad',
#   'gladly',
#   'glamorous',
#   'glee',
#   'gleefully',
#   'glimmer',
#   'glimmering',
#   'glisten',
#   'glistening',
#   'glitter',
#   'glitz',
#   'glorify',
#   'glorious',
#   'gloriously',
#   'glory',
#   'glow',
#   'glowing',
#   'god-send',
#   'godlike',
#   'godsend',
#   'gold',
#   'golden',
#   'good',
#   'goodly',
#   'goodness',
#   'goodwill',
#   'goood',
#   'gooood',
#   'gorgeous',
#   'gorgeously',
#   'grace',
#   'graceful',
#   'gracefully',
#   'gracious',
#   'graciously',
#   'grand',
#   'grandeur',
#   'grateful',
#   'gratefully',
#   'gratification',
#   'gratified',
#   'gratifying',
#   'gratitude',
#   'great',
#   'greatest',
#   'greatness',
#   'grin',
#   'groundbreaking',
#   'guarantee',
#   'guidance',
#   'gumption',
#   'gush',
#   'gusto',
#   'gutsy',
#   'hail',
#   'hale',
#   'hallmark',
#   'hallmarks',
#   'hallowed',
#   'handier',
#   'handily',
#   'hands-down',
#   'handsome',
#   'handsomely',
#   'handy',
#   'happier',
#   'happily',
#   'happiness',
#   'happy',
#   'hard-working',
#   'hardier',
#   'hardy',
#   'harmless',
#   'harmonious',
#   'harmoniously',
#   'harmony',
#   'headway',
#   'heal',
#   'healthful',
#   'healthy',
#   'heartfelt',
#   'heartily',
#   'heartwarming',
#   'heaven',
#   'heavenly',
#   'helped',
#   'helpful',
#   'helping',
#   'hero',
#   'heroic',
#   'heroine',
#   'heros',
#   'high-quality',
#   'hilarious',
#   'holy',
#   'homage',
#   'honest',
#   'honesty',
#   'honor',
#   'honorable',
#   'honored',
#   'honoring',
#   'hooray',
#   'hopeful',
#   'hot',
#   'hotcakes',
#   'hottest',
#   'hug',
#   'humane',
#   'humble',
#   'humility',
#   'humor',
#   'humorous',
#   'humorously',
#   'humour',
#   'ideal',
#   'ideally',
#   'idol',
#   'idyllic',
#   'illuminate',
#   'illuminating',
#   'illustrious',
#   'imaginative',
#   'immaculate',
#   'immaculately',
#   'immense',
#   'impartial',
#   'impartiality',
#   'impartially',
#   'impeccable',
#   'impeccably',
#   'important',
#   'impress',
#   'impressed',
#   'impresses',
#   'impressive',
#   'impressively',
#   'improve',
#   'improved',
#   'improvement',
#   'improvements',
#   'improves',
#   'improving',
#   'incredible',
#   'incredibly',
#   'indebted',
#   'individualized',
#   'indulgence',
#   'indulgent',
#   'industrious',
#   'inexpensive',
#   'infallible',
#   'influential',
#   'ingenious',
#   'ingeniously',
#   'ingenuity',
#   'ingenuous',
#   'innocuous',
#   'innovation',
#   'innovative',
#   'inpressed',
#   'insightful',
#   'inspiration',
#   'inspirational',
#   'inspire',
#   'inspiring',
#   'instantly',
#   'instructive',
#   'instrumental',
#   'integral',
#   'integrated',
#   'intelligence',
#   'intelligent',
#   'intelligible',
#   'interesting',
#   'interests',
#   'intimacy',
#   'intimate',
#   'intricate',
#   'intrigue',
#   'intriguing',
#   'intuitive',
#   'invaluable',
#   'inventive',
#   'invigorating',
#   'invincible',
#   'invulnerable',
#   'irreplaceable',
#   'irresistible',
#   'issue-free',
#   'jaw-dropping',
#   'jolly',
#   'joy',
#   'joyful',
#   'joyfully',
#   'joyous',
#   'judicious',
#   'justly',
#   'keen',
#   'keenly',
#   'kid-friendly',
#   'kindly',
#   'kindness',
#   'knowledgeable',
#   'kudos',
#   'large-capacity',
#   'laud',
#   'laudable',
#   'lavish',
#   'law-abiding',
#   'lawful',
#   'lead',
#   'leading',
#   'leads',
#   'lean',
#   'led',
#   'legendary',
#   'leverage',
#   'liberate',
#   'liberation',
#   'liberty',
#   'lifesaver',
#   'lighter',
#   'likable',
#   'like',
#   'liked',
#   'likes',
#   'liking',
#   'lively',
#   'logical',
#   'long-lasting',
#   'lovable',
#   'love',
#   'loved',
#   'lovely',
#   'lover',
#   'loves',
#   'loving',
#   'low-cost',
#   'low-price',
#   'low-priced',
#   'low-risk',
#   'lower-priced',
#   'loyal',
#   'loyalty',
#   'lucid',
#   'luck',
#   'luckier',
#   'luckiest',
#   'lucky',
#   'lucrative',
#   'luminous',
#   'lush',
#   'luster',
#   'lustrous',
#   'luxuriant',
#   'luxurious',
#   'luxuriously',
#   'luxury',
#   'lyrical',
#   'magic',
#   'magical',
#   'magnificence',
#   'magnificent',
#   'magnificently',
#   'majestic',
#   'majesty',
#   'manageable',
#   'maneuverable',
#   'marvel',
#   'marveled',
#   'marvelled',
#   'marvellous',
#   'marvelous',
#   'marvelously',
#   'marvels',
#   'master',
#   'masterful',
#   'masterfully',
#   'masterpiece',
#   'masterpieces',
#   'masters',
#   'mastery',
#   'matchless',
#   'mature',
#   'maturity',
#   'meaningful',
#   'memorable',
#   'merciful',
#   'mercifully',
#   'mercy',
#   'merit',
#   'merrily',
#   'merry',
#   'mesmerize',
#   'mesmerized',
#   'mesmerizing',
#   'meticulous',
#   'meticulously',
#   'mightily',
#   'mighty',
#   'mind-blowing',
#   'miracle',
#   'miracles',
#   'miraculous',
#   'miraculously',
#   'modern',
#   'modest',
#   'modesty',
#   'momentous',
#   'monumental',
#   'monumentally',
#   'morality',
#   'motivated',
#   'multi-purpose',
#   'navigable',
#   'neat',
#   'neatest',
#   'neatly',
#   'nice',
#   'nicely',
#   'nicer',
#   'nicest',
#   'nifty',
#   'nimble',
#   'noble',
#   'noiseless',
#   'non-violent',
#   'notably',
#   'noteworthy',
#   'nourishment',
#   'novelty',
#   'nurturing',
#   'oasis',
#   'obsession',
#   'obtainable',
#   'openly',
#   'openness',
#   'optimal',
#   'optimism',
#   'optimistic',
#   'opulent',
#   'orderly',
#   'originality',
#   'outdo',
#   'outdone',
#   'outperform',
#   'outperformed',
#   'outperforming',
#   'outperforms',
#   'outshine',
#   'outshone',
#   'outsmart',
#   'outstanding',
#   'outstandingly',
#   ...],
#  'hindi': ['abound',
#   'abounds',
#   'abundance',
#   'हुस्न',
#   'accessable',
#   'सुलभ',
#   'acclaim',
#   'acclaimed',
#   'accolade',
#   'accolades',
#   'पूरा',
#   'पूरा हुआ',
#   'उपलब्धि',
#   'उपलब्धियों',
#   'सटीक',
#   'यथासंभव',
#   'achievable',
#   'उपलब्धि',
#   'उपलब्धियाँ',
#   'कौशल',
#   'adaptable',
#   'adaptive',
#   'adequate',
#   'समायोजनीय',
#   'प्रशंसनीय',
#   'admirably',
#   'admiration',
#   'प्रशंसा',
#   'प्रशंसक',
#   'admiring',
#   'प्यारे',
#   'प्यार करता हूँ',
#   'adored',
#   'adulation',
#   'उन्नत',
#   'लाभ',
#   'advantageous',
#   'लाभ',
#   'adventuresome',
#   'adventurous',
#   'advocate',
#   'advocated',
#   'हिन्दुत्व की',
#   'स्नेह',
#   'affectionate',
#   'संबंध',
#   'affirm',
#   'affirmation',
#   'सकारात्मक',
#   'affluence',
#   'affluent',
#   'बर्दाश्त',
#   'किफायती',
#   'affordably',
#   'afordable',
#   'एजाइल',
#   'की फुर्ती',
#   'agreeable',
#   'agreeably',
#   'all-around',
#   'सम्मोहक',
#   'altruistic',
#   'आश्चर्यचकित करो',
#   'हैरान',
#   'amazement',
#   'amazes',
#   'अद्भुत',
#   'आश्चर्यजनक',
#   'महत्वाकांक्षी होते',
#   'ameliorate',
#   'amenable',
#   'amicable',
#   'amity',
#   'पर्याप्त',
#   'amply',
#   'amuse',
#   'amusing',
#   'amusingly',
#   'परी',
#   'ऐंजेलिक',
#   'apotheosis',
#   'अपील',
#   'ऐसे मोहक',
#   'applaud',
#   'appreciable',
#   'की सराहना करते हैं',
#   'सराहना करते हैं',
#   'appreciates',
#   'appreciative',
#   'उपयुक्त',
#   'अनुमोदन',
#   'अनुमोदन',
#   'ardent',
#   'articulate',
#   'aspiration',
#   'aspirations',
#   'अस्पायर',
#   'आश्वासन',
#   'आश्वासन की',
#   'assure',
#   'assuredly',
#   'सुनिश्चित करने वाले',
#   'astonish',
#   'बडा आश्चर्यचकित',
#   'चौंकाने वाले',
#   'astonishingly',
#   'astonishment',
#   'astound',
#   'astounded',
#   'आश्चर्यजनक रूप से प्रभावशाली',
#   'astoundingly',
#   'सचेत',
#   'आकर्षण',
#   'आकर्षक',
#   'आकर्षक',
#   'audible',
#   'audibly',
#   'बनाते हैं',
#   'प्रामाणिक',
#   'authoritative',
#   'खुला',
#   'उपलब्ध',
#   'aver',
#   'avid',
#   'avidly',
#   'पुरस्कार',
#   'से सम्मानित',
#   'पुरस्कार',
#   'कर देंगें',
#   'awed',
#   'बेहतरीन',
#   'awesomely',
#   'awesomeness',
#   'awestruck',
#   'कमाल का',
#   'मेरुदंड होता है',
#   'संतुलित',
#   'सौदा',
#   'सुंदर',
#   'खूबसूरती से',
#   'शोभा बढ़ाए',
#   'सौंदर्य',
#   'believable',
#   'प्रिय',
#   'benefactor',
#   'फायदेमंद',
#   'लाभार्थी का',
#   'लाभ',
#   'लाभ',
#   'benevolence',
#   'benevolent',
#   'benifits',
#   'सर्वश्रेष्ठ',
#   'best-known',
#   'best-performing',
#   'best-selling',
#   'बेहतर',
#   'better-known',
#   'better-than-expected',
#   'beutifully',
#   'blameless',
#   'आशीर्वाद',
#   'आशीर्वाद',
#   'आनंद',
#   'blissful',
#   'blissfully',
#   'blockbuster',
#   'bloom',
#   'खिलना',
#   'ग्लोबस',
#   'बोनस',
#   'बोनस',
#   'बूम',
#   'रहा',
#   'को बढ़ावा देने के लिए',
#   'boundless',
#   'bountiful',
#   'जानिए तेज दिमाग',
#   'brand-new',
#   'बहादुर',
#   'bravery',
#   'ब्रावो',
#   'breakthrough',
#   'breakthroughs',
#   'breathlessness',
#   'लुभावनी',
#   'breathtakingly',
#   'मंद हवा',
#   'चमकीले मेल खाते परिधानों से करें',
#   'चमकाने',
#   'brighter',
#   'brightest',
#   'ब्रिलिएंस',
#   'चमकदार माणिक जैसा',
#   'brilliantly',
#   'तेज़ी से',
#   'भाई का',
#   'buoyant',
#   'cajole',
#   'शांति',
#   'calming',
#   'क्षमता',
#   'योग्य',
#   'capably',
#   'captivate',
#   'मनोरम',
#   'तनावमुक्त',
#   'cashback',
#   'catchy',
#   'का उत्सव मना रहे हैं',
#   'मनाया',
#   'जश्न',
#   'विजेता',
#   'चैंपियन',
#   'आकर्षण है',
#   'करिश्माई महिलाओं',
#   'धर्मार्थ',
#   'आकर्षण',
#   'आकर्षक',
#   'charmingly',
#   'सस्ता',
#   'सस्ता',
#   'खुश हो जाओ',
#   'खूबसूरत',
#   'cheery',
#   'cherish',
#   'cherished',
#   'फैशनेबल',
#   'स्पष्टता',
#   'क्लासिक',
#   'सर्वोत्कृष्ट',
#   'साफ',
#   'क्लीनर',
#   'cleanest',
#   'स्वच्छता एक बड़ा मुद्दा बन चुका',
#   'cleanly',
#   'स्पष्ट',
#   'clear-cut',
#   'मिट',
#   'clearer',
#   'स्पष्ट रूप से',
#   'clears',
#   'चालाक',
#   'cleverly',
#   'coherence',
#   'coherent',
#   'cohesive',
#   'रंगीन तरीके से तैयार किया गया है',
#   'आराम',
#   'आरामदायक',
#   'आराम',
#   'comforting',
#   'आरामदायक',
#   'commend',
#   'commendable',
#   'commendably',
#   'वचनबद्धता',
#   'commodious',
#   'कॉम्पैक्ट',
#   'compactly',
#   'करुणा कठोर मेरा',
#   'दयावान',
#   'अनुकूल',
#   'प्रतिस्पर्धी',
#   'पूरक',
#   'पूरक',
#   'complemented',
#   'पूरक',
#   'अनुरूप',
#   'प्रशंसा',
#   'निशुल्क',
#   'व्यापक',
#   'conciliatory',
#   'संक्षिप्त',
#   'आत्मविश्वास',
#   'confident',
#   'congenial',
#   'congratulate',
#   'बधाई',
#   'बधाई',
#   'conscientious',
#   'considerate',
#   'संगत',
#   'लगातार',
#   'रचनात्मक',
#   'consummate',
#   'contentment',
#   'कंटीन्यूटी',
#   'contrasty',
#   'योगदान',
#   'सुविधा',
#   'सुविधाजनक',
#   'conveniently',
#   'convience',
#   'convienient',
#   'convient',
#   'ठोस',
#   'convincingly',
#   'कूल',
#   'ठंडा',
#   'अधिक सहयोगी',
#   'आधारशिला',
#   'सही',
#   'सही ढंग से',
#   'cost-effective',
#   'cost-saving',
#   'साहस',
#   'साहसी',
#   'विनम्र',
#   'प्रण',
#   'आरामदायक',
#   'रचनात्मक',
#   'credence',
#   'प्रामाणिक',
#   'कड़क',
#   'crisper',
#   'इलाज',
#   'cure-all',
#   'cushy',
#   'प्यारा',
#   'cuteness',
#   'साहसी',
#   'डार्लिंग',
#   'dashing',
#   'सूर्योदय',
#   'चमक',
#   'dazzled',
#   'चमकदार',
#   'dead-on',
#   'decency',
#   'सभ्य',
#   'निर्णायक',
#   'समर्पित',
#   'सबसे बड़ी हार दी',
#   'जानवर को हराया',
#   'को हराकर',
#   'defeats',
#   'defender',
#   'deference',
#   'deft',
#   'delectable',
#   'delicacy',
#   'कोमलता से',
#   'स्वादिष्ट लगते हैं ।',
#   'डिलाईट',
#   'delighted',
#   'delightful',
#   'delightfully',
#   'विश्वसनीय',
#   'dependably',
#   'deservedly',
#   'deserving',
#   'वांछनीय',
#   'की इच्छा होगा',
#   'भाग्य',
#   'detachable',
#   'devout',
#   'dexterous',
#   'dextrous',
#   'dignified',
#   'इज्जत',
#   'diligence',
#   'diligent',
#   'diligently',
#   'diplomatic',
#   'dirt-cheap',
#   'distinction',
#   'distinctive',
#   'प्रतिष्ठित',
#   'diversified',
#   'डीवाइन',
#   'dominate',
#   'छाई',
#   'dominates',
#   'doubtless',
#   'dreamland',
#   'dumbfounded',
#   'dummy-proof',
#   'टिकाऊ',
#   'गतिशील',
#   'उत्सुक',
#   'बेसब्री से',
#   'eagerness',
#   'earnest',
#   'earnestly',
#   'सरलता',
#   'eased',
#   'eases',
#   'इतना आसान नहीं था',
#   'सबसे आसान',
#   'easiness',
#   'बैंक द्वारा मुद्रा की आपूर्ति में नई मुद्रा की शुरुआत',
#   'आसान',
#   'easy-to-use',
#   'easygoing',
#   'ebullience',
#   'किफायती',
#   'ecstasy',
#   'ecstatic',
#   'ecstatically',
#   'शिक्षित',
#   'प्रभावी',
#   'से रोक',
#   'प्रभावशीलता',
#   'कुशल',
#   'इनके कुशलता से',
#   'effortless',
#   'effortlessly',
#   'बहाव का कारण बनता है',
#   'effusive',
#   'जोश',
#   'elated',
#   'elation',
#   'भव्यता से युक्त बनाता है',
#   'सुंदर',
#   'elegantly',
#   'भा जाएँ',
#   'इलीट',
#   'eloquence',
#   'eloquent',
#   'eloquently',
#   'eminence',
#   'प्रख्यात',
#   'empathize',
#   'empathy',
#   'को सशक्त करें',
#   'अधिकारिता',
#   'enchanted',
#   'करामाती',
#   'प्रोत्साहित करें',
#   'प्रोत्साहित करने',
#   'उत्साहजनक',
#   'endear',
#   'endearing',
#   'समर्थन करें',
#   'समर्थित',
#   'परांकन',
#   'endorses',
#   'endorsing',
#   'energetic',
#   'energize',
#   'energy-efficient',
#   'energy-saving',
#   'आकर्षक',
#   'engrossing',
#   'को निखारेंगे',
#   'संवर्धित',
#   'वृद्धि',
#   'रंग',
#   'का आनंद लें',
#   'आनंददायक',
#   'enjoyably',
#   'मज़ा आया',
#   'का आनंद लेते हुए',
#   'गुल खिलना',
#   'enjoys',
#   'enlighten',
#   'आत्मज्ञान',
#   'पर्याप्त',
#   'enraptured',
#   'वाले जीव',
#   'enrichment',
#   'enterprising',
#   'मनोरंजन',
#   'मनोरंजक',
#   'entertains',
#   'enthralled',
#   'enthusiasm',
#   'उत्साही',
#   'उत्साही',
#   'enthusiastically',
#   'प्रलोभन मिलता है',
#   'enticed',
#   'की मोहकता',
#   'entranced',
#   'entrancing',
#   'entrust',
#   'enviable',
#   'सम्मोहक',
#   'enviously',
#   'ईर्ष्या के बीज',
#   'equitable',
#   'ergonomical',
#   'नैतिक',
#   'euphoria',
#   'euphoric',
#   'evaluative',
#   'evenly',
#   'eventful',
#   'सदाबहार',
#   'evocative',
#   'पार',
#   'पार हो चुका है',
#   'से अधिक',
#   'exceedingly',
#   'से अधिक',
#   'एक्सेल',
#   'excelent',
#   'excellant',
#   'excelled',
#   'श्रेष्ठता',
#   'excellency',
#   'उत्कृष्ट',
#   'विशेष रूप',
#   'excels',
#   'असाधारण',
#   'विशि\u200dष्ट रूप से',
#   'excite',
#   'उत्तेजित',
#   'excitedly',
#   'रोमांच',
#   'excites',
#   'रोमांचक',
#   'exellent',
#   'exemplary',
#   'exhilarating',
#   'exhilaration',
#   'expansive',
#   'expeditiously',
#   'expertly',
#   'उत्कृष्ट',
#   'exquisitely',
#   'extol',
#   'extoll',
#   'extraordinarily',
#   'असाधारण',
#   'exuberant',
#   'मनमोहक',
#   'eyecatching',
#   'शानदार',
#   'fabulously',
#   'facilitate',
#   'मेला',
#   'काफी',
#   'निष्पक्षता',
#   'विश्वास',
#   'वफादार',
#   'विश्वासपात्र',
#   'faithfulness',
#   'फेम',
#   'famed',
#   'प्रसिद्ध',
#   'famously',
#   'अधिक रुचिकर',
#   'फैंसी',
#   'fanfare',
#   'प्रशंसकों को आवाज़ दी जाती है',
#   'शानदार',
#   'fantastically',
#   'मोहित',
#   'दिलचस्प रंगीन',
#   'fascination',
#   'फैशनेबल',
#   'fashionably',
#   'तेज',
#   'fast-paced',
#   'तेज',
#   'तेज',
#   'faultless',
#   'मनपसंद',
#   'पक्ष लेने',
#   'अहसान',
#   'अनुकूल',
#   'favored',
#   'पसंदीदा',
#   'पक्ष',
#   'दंबगों',
#   'feasible',
#   'feasibly',
#   'फीट',
#   'feature-rich',
#   'साहसी',
#   'फ़र्टाइल',
#   'fervent',
#   'fervently',
#   'fervor',
#   'जलवा',
#   'निष्ठा',
#   'तेजस्वी',
#   'ठीक',
#   'से बने',
#   'बेहतर',
#   'बेहतरीन',
#   'firmer',
#   'first-class',
#   'first-rate',
#   'flashy',
#   'flatter',
#   'प्रशंसनीय',
#   'फ्लॉलेस',
#   'flawlessly',
#   'लचीलेपन को विकसित करता है',
#   'लचीला',
#   'flourish',
#   'flourishing',
#   'निपुण',
#   'स्पंदन',
#   'शौकीन',
#   'fondly',
#   'fondness',
#   'foolproof',
#   'महत्वपूर्ण',
#   'foresight',
#   'formidable',
#   'fortitude',
#   'fortuitous',
#   'fortuitously',
#   'भाग्यशाली',
#   'सौभाग्य से',
#   'भाग्य',
#   'नि : शुल्क',
#   'freed',
#   'स्वतंत्रता',
#   'freedoms',
#   'ताजा',
#   'fresher',
#   'freshest',
#   'friendliness',
#   'अनुकूल',
#   'frolic',
#   'frugal',
#   'fruitful',
#   'ftw',
#   'पूर्ति',
#   'मजेदार',
#   'भविष्यउन्मुखी',
#   'gaiety',
#   'बढ़ना',
#   'कर पाई',
#   'gaining',
#   'मजबूत',
#   'gallant',
#   'प्रचुर मात्रा में',
#   'geeky',
#   'रत्न',
#   'रत्न पहने जाएँ',
#   'generosity',
#   'उदार',
#   'generously',
#   'genial',
#   'प्रतिभा',
#   'जेंटल',
#   'gentlest',
#   'असली',
#   'प्रतिभाशाली',
#   'खुशी हुई',
#   'gladly',
#   'आपके वॉरड्रोब मे',
#   'glee',
#   'gleefully',
#   'glimmer',
#   'glimmering',
#   'glisten',
#   'glistening',
#   'चमकीली',
#   'तड़क - भड़क',
#   'को निखारने',
#   'glorious',
#   'gloriously',
#   'ग्लोरी',
#   'चमक को सुनिश्चित करता है',
#   'चमकना',
#   'god-send',
#   'godlike',
#   'का',
#   'सोना',
#   'गोल्डन',
#   'अच्छा',
#   'goodly',
#   'अच्छाई',
#   'goodwill',
#   'goood',
#   'gooood',
#   'खूबसूरत',
#   'gorgeously',
#   'ग्रेस के प्रेम में बुरी तरह पागल हैं',
#   'गरीमामय',
#   'gracefully',
#   'विनीत',
#   'graciously',
#   'ग्रैंड',
#   'grandeur',
#   'आभारी',
#   'gratefully',
#   'gratification',
#   'gratified',
#   'संतुष्टिदायक',
#   'नम',
#   'महान',
#   'महान',
#   'महानता',
#   'मुसकुराहट',
#   'अभूतपूर्व',
#   'गारंटी',
#   'मार्गदर्शन',
#   'gumption',
#   'gush',
#   'जोश दिखाओ',
#   'gutsy',
#   'जय',
#   'hale',
#   'प्रमाण चिन्ह',
#   'hallmarks',
#   'hallowed',
#   'handier',
#   'handily',
#   'hands-down',
#   'सुंदर',
#   'handsomely',
#   'सुलभ',
#   'खुश',
#   'खुशी से',
#   'खुशी',
#   'खुश',
#   'hard-working',
#   'hardier',
#   'पीछे बैठने वाले',
#   'हानिरहित',
#   'harmonious',
#   'harmoniously',
#   'मेल मिलाप',
#   'headway',
#   'चंगा',
#   'healthful',
#   'स्वस्थ',
#   'heartfelt',
#   'heartily',
#   'दिली',
#   'स्वर्ग',
#   'अलौकिक',
#   'कुछ किया',
#   'सहायक',
#   'मदद के लिए',
#   'हीरो',
#   'heroic',
#   'हीरोइन',
#   'heros',
#   'high-quality',
#   'प्रफुल्लित करने वाला',
#   'पवित्र',
#   'जलसा शायरे',
#   'ईमानदार',
#   'ईमानदारी',
#   'सम्मान',
#   'सम्मानित',
#   'सम्मानित',
#   'honoring',
#   'हुर्रे',
#   'अच्छा',
#   'गर्म',
#   'hotcakes',
#   'हॉटैस्ट',
#   'आलिंगन',
#   'मानव',
#   'विनम्र',
#   'humility',
#   'हास्य',
#   'humorous',
#   'humorously',
#   'humour',
#   'आदर्श रंग और स्टाइल आपके आकर्षण में चार चांद लगा',
#   'आदर्श रूप में',
#   'आइडल',
#   'idyllic',
#   'illuminate',
#   'illuminating',
#   'illustrious',
#   'इमेजनेटिव',
#   'त्रुटिहीन',
#   'immaculately',
#   'विशाल',
#   'impartial',
#   'impartiality',
#   'impartially',
#   'impeccable',
#   'impeccably',
#   'महत्वपूर्ण',
#   'प्रभावित',
#   'प्रभावित',
#   'impresses',
#   'प्रभावशील',
#   'impressively',
#   'में सुधार',
#   'सुधार',
#   'सुधार',
#   'सुधार',
#   'शारीरिक',
#   'improving',
#   'अविश्वसनीय',
#   'अविश्वसनीय रूप से',
#   'indebted',
#   'individualized',
#   'indulgence',
#   'indulgent',
#   'industrious',
#   'सस्ती',
#   'अचूक',
#   'प्रभावशाली',
#   'ingenious',
#   'ingeniously',
#   'ingenuity',
#   'ingenuous',
#   'innocuous',
#   'नवाचार',
#   'नवीन',
#   'inpressed',
#   'पुरे जानकारीपूर्ण',
#   'प्रेरणा',
#   'प्रेरणादायक',
#   'प्रेरित',
#   'प्रेरक',
#   'तुरन्त',
#   'instructive',
#   'instrumental',
#   'एकीकृत',
#   'एकीकृत',
#   'बुद्धि',
#   'बुद्धिमान',
#   'intelligible',
#   'दिलचस्प',
#   'हितों',
#   'अंतरंगता',
#   'इंटीमेट',
#   'बारीक',
#   'intrigue',
#   'पेचीदा',
#   'मज़ेदार',
#   'invaluable',
#   'inventive',
#   'invigorating',
#   'अजेय',
#   'invulnerable',
#   'irreplaceable',
#   'प्रबल',
#   'issue-free',
#   'jaw-dropping',
#   'जॉली',
#   'आनन्द',
#   'joyful',
#   'joyfully',
#   'joyous',
#   'judicious',
#   'justly',
#   'उतावला',
#   'keenly',
#   'kid-friendly',
#   'कृपया',
#   'दया',
#   'ज्ञान है',
#   'तारीफ',
#   'large-capacity',
#   'laud',
#   'laudable',
#   'lavish',
#   'law-abiding',
#   'विधिमान्य',
#   'नेतृत्व',
#   'प्रमुख',
#   'आगे ले जाती है',
#   'दुबला',
#   'श्रेष्ठ चमकीली खास तौर पर निर्मित एलईडी',
#   'पौराणिक',
#   'लाभ उठाएं',
#   'पाप सँ मुक्ति प्रदान करू',
#   'liberation',
#   'लिबर्टी',
#   'lifesaver',
#   'हल्का',
#   'likable',
#   'की तरह',
#   'पसंद आया',
#   'पसंद करती है',
#   'पसंद',
#   'जीवंत',
#   'तार्किक',
#   'long-lasting',
#   'lovable',
#   'प्यार',
#   'प्यार किया',
#   'प्यारा',
#   'प्रेमी',
#   'प्यार करता है',
#   'प्यार करना',
#   'low-cost',
#   'low-price',
#   'low-priced',
#   'low-risk',
#   'lower-priced',
#   'वफादार',
#   'वफादारी',
#   'स्पष्ट अर्थ का',
#   'भाग्य',
#   'luckier',
#   'luckiest',
#   'भाग्यशाली',
#   'lucrative',
#   'चमकदार',
#   'रसीला',
#   'आभा',
#   'lustrous',
#   'luxuriant',
#   'luxurious',
#   'luxuriously',
#   'लग्ज़री',
#   'lyrical',
#   'जादू',
#   'जादुई',
#   'magnificence',
#   'शानदार',
#   'magnificently',
#   'आलीशान',
#   'majesty',
#   'manageable',
#   'maneuverable',
#   'अचंभा',
#   'marveled',
#   'marvelled',
#   'अद्भुत',
#   'लजीज',
#   'marvelously',
#   'marvels',
#   'मास्टर',
#   'masterful',
#   'masterfully',
#   'मास्टरपीस',
#   'masterpieces',
#   'स्वामी',
#   'mastery',
#   'matchless',
#   'परिपक्व',
#   'परिपक्वता',
#   'meaningful',
#   'यादगार',
#   'दयालु',
#   'mercifully',
#   'दया',
#   'शिक्षक अभ्यर्थियों की मेधा',
#   'merrily',
#   'मैरी',
#   'mesmerize',
#   'mesmerized',
#   'मन मोह लेने वाले',
#   'सूक्ष्म',
#   'meticulously',
#   'mightily',
#   'पराक्रमी',
#   'जो आपके होश उड़ा देगी !',
#   'चमत्कार',
#   'चमत्कारों',
#   'तिलस्मी',
#   'miraculously',
#   'आधुनिक',
#   'modest',
#   'इस लोक',
#   'momentous',
#   'यादगार मौका होता',
#   'monumentally',
#   'नैतिकता',
#   'प्रेरित',
#   'multi-purpose',
#   'navigable',
#   'साफ',
#   'neatest',
#   'अच्छे से',
#   'अच्छा',
#   'अच्छी तरह से',
#   'nicer',
#   'nicest',
#   'nifty',
#   'nimble',
#   'नोबल',
#   'noiseless',
#   'non-violent',
#   'notably',
#   'उल्लेखनीय',
#   'nourishment',
#   'novelty',
#   'nurturing',
#   'ओएसिस',
#   'जूनून',
#   'obtainable',
#   'का , खुलकर करें बखान',
#   'openness',
#   'इष्टतम',
#   'आशावाद',
#   'आशावादी',
#   'opulent',
#   'व्यवस्थित',
#   'originality',
#   'outdo',
#   'ने',
#   'सोकर',
#   'outperformed',
#   'outperforming',
#   'outperforms',
#   'outshine',
#   'outshone',
#   'outsmart',
#   'बकाया',
#   'outstandingly',
#   ...],
#  'polarity': ['positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   'positive',
#   ...]}

# %%
new_bilingiu = pd.DataFrame(new_biling_dict)

# %%
new_bilingiu[new_bilingiu["english"]=="good"]
# Out:
#     english  hindi  polarity
# 667    good  अच्छा  positive

# %%
new_bilingiu['hindi'].value_counts()
# Out:
# शानदार           6
# का               6
# तेज              5
# आकर्षक           5
# पागल             5
#                 ..
# snazzy           1
# घातक             1
# reproach         1
# scourge          1
# rollercoaster    1
# Name: hindi, Length: 4687, dtype: int64

# %%
new_bilingiu
# Out:
#          english       hindi  polarity
# 0         abound      abound  positive
# 1        abounds     abounds  positive
# 2      abundance   abundance  positive
# 3       abundant       हुस्न  positive
# 4     accessable  accessable  positive
# ...          ...         ...       ...
# 5006      zapped      zapped  negative
# 5007        zaps        zaps  negative
# 5008      zealot      zealot  negative
# 5009     zealous     zealous  negative
# 5010      zombie      ज़ोंबी  negative
#
# [5011 rows x 3 columns]

# %%
list(new_bilingiu["english"].values)
# Out:
# ['abound',
#  'abounds',
#  'abundance',
#  'abundant',
#  'accessable',
#  'accessible',
#  'acclaim',
#  'acclaimed',
#  'accolade',
#  'accolades',
#  'accomplish',
#  'accomplished',
#  'accomplishment',
#  'accomplishments',
#  'accurate',
#  'accurately',
#  'achievable',
#  'achievement',
#  'achievements',
#  'acumen',
#  'adaptable',
#  'adaptive',
#  'adequate',
#  'adjustable',
#  'admirable',
#  'admirably',
#  'admiration',
#  'admire',
#  'admirer',
#  'admiring',
#  'adorable',
#  'adore',
#  'adored',
#  'adulation',
#  'advanced',
#  'advantage',
#  'advantageous',
#  'advantages',
#  'adventuresome',
#  'adventurous',
#  'advocate',
#  'advocated',
#  'advocates',
#  'affection',
#  'affectionate',
#  'affinity',
#  'affirm',
#  'affirmation',
#  'affirmative',
#  'affluence',
#  'affluent',
#  'afford',
#  'affordable',
#  'affordably',
#  'afordable',
#  'agile',
#  'agility',
#  'agreeable',
#  'agreeably',
#  'all-around',
#  'alluring',
#  'altruistic',
#  'amaze',
#  'amazed',
#  'amazement',
#  'amazes',
#  'amazing',
#  'amazingly',
#  'ambitious',
#  'ameliorate',
#  'amenable',
#  'amicable',
#  'amity',
#  'ample',
#  'amply',
#  'amuse',
#  'amusing',
#  'amusingly',
#  'angel',
#  'angelic',
#  'apotheosis',
#  'appeal',
#  'appealing',
#  'applaud',
#  'appreciable',
#  'appreciate',
#  'appreciated',
#  'appreciates',
#  'appreciative',
#  'appropriate',
#  'approval',
#  'approve',
#  'ardent',
#  'articulate',
#  'aspiration',
#  'aspirations',
#  'aspire',
#  'assurance',
#  'assurances',
#  'assure',
#  'assuredly',
#  'assuring',
#  'astonish',
#  'astonished',
#  'astonishing',
#  'astonishingly',
#  'astonishment',
#  'astound',
#  'astounded',
#  'astounding',
#  'astoundingly',
#  'attentive',
#  'attraction',
#  'attractive',
#  'attractively',
#  'audible',
#  'audibly',
#  'auspicious',
#  'authentic',
#  'authoritative',
#  'autonomous',
#  'available',
#  'aver',
#  'avid',
#  'avidly',
#  'award',
#  'awarded',
#  'awards',
#  'awe',
#  'awed',
#  'awesome',
#  'awesomely',
#  'awesomeness',
#  'awestruck',
#  'awsome',
#  'backbone',
#  'balanced',
#  'bargain',
#  'beautiful',
#  'beautifully',
#  'beautify',
#  'beauty',
#  'believable',
#  'beloved',
#  'benefactor',
#  'beneficial',
#  'beneficiary',
#  'benefit',
#  'benefits',
#  'benevolence',
#  'benevolent',
#  'benifits',
#  'best',
#  'best-known',
#  'best-performing',
#  'best-selling',
#  'better',
#  'better-known',
#  'better-than-expected',
#  'beutifully',
#  'blameless',
#  'bless',
#  'blessing',
#  'bliss',
#  'blissful',
#  'blissfully',
#  'blockbuster',
#  'bloom',
#  'blossom',
#  'bolster',
#  'bonus',
#  'bonuses',
#  'boom',
#  'booming',
#  'boost',
#  'boundless',
#  'bountiful',
#  'brainy',
#  'brand-new',
#  'brave',
#  'bravery',
#  'bravo',
#  'breakthrough',
#  'breakthroughs',
#  'breathlessness',
#  'breathtaking',
#  'breathtakingly',
#  'breeze',
#  'bright',
#  'brighten',
#  'brighter',
#  'brightest',
#  'brilliance',
#  'brilliant',
#  'brilliantly',
#  'brisk',
#  'brotherly',
#  'buoyant',
#  'cajole',
#  'calm',
#  'calming',
#  'capability',
#  'capable',
#  'capably',
#  'captivate',
#  'captivating',
#  'carefree',
#  'cashback',
#  'catchy',
#  'celebrate',
#  'celebrated',
#  'celebration',
#  'champ',
#  'champion',
#  'charisma',
#  'charismatic',
#  'charitable',
#  'charm',
#  'charming',
#  'charmingly',
#  'cheaper',
#  'cheapest',
#  'cheer',
#  'cheerful',
#  'cheery',
#  'cherish',
#  'cherished',
#  'chic',
#  'clarity',
#  'classic',
#  'classy',
#  'clean',
#  'cleaner',
#  'cleanest',
#  'cleanliness',
#  'cleanly',
#  'clear',
#  'clear-cut',
#  'cleared',
#  'clearer',
#  'clearly',
#  'clears',
#  'clever',
#  'cleverly',
#  'coherence',
#  'coherent',
#  'cohesive',
#  'colorful',
#  'comfort',
#  'comfortable',
#  'comfortably',
#  'comforting',
#  'comfy',
#  'commend',
#  'commendable',
#  'commendably',
#  'commitment',
#  'commodious',
#  'compact',
#  'compactly',
#  'compassion',
#  'compassionate',
#  'compatible',
#  'competitive',
#  'complement',
#  'complementary',
#  'complemented',
#  'complements',
#  'compliant',
#  'compliment',
#  'complimentary',
#  'comprehensive',
#  'conciliatory',
#  'concise',
#  'confidence',
#  'confident',
#  'congenial',
#  'congratulate',
#  'congratulation',
#  'congratulations',
#  'conscientious',
#  'considerate',
#  'consistent',
#  'consistently',
#  'constructive',
#  'consummate',
#  'contentment',
#  'continuity',
#  'contrasty',
#  'contribution',
#  'convenience',
#  'convenient',
#  'conveniently',
#  'convience',
#  'convienient',
#  'convient',
#  'convincing',
#  'convincingly',
#  'cool',
#  'coolest',
#  'cooperative',
#  'cornerstone',
#  'correct',
#  'correctly',
#  'cost-effective',
#  'cost-saving',
#  'courage',
#  'courageous',
#  'courteous',
#  'covenant',
#  'cozy',
#  'creative',
#  'credence',
#  'credible',
#  'crisp',
#  'crisper',
#  'cure',
#  'cure-all',
#  'cushy',
#  'cute',
#  'cuteness',
#  'daring',
#  'darling',
#  'dashing',
#  'dawn',
#  'dazzle',
#  'dazzled',
#  'dazzling',
#  'dead-on',
#  'decency',
#  'decent',
#  'decisive',
#  'dedicated',
#  'defeat',
#  'defeated',
#  'defeating',
#  'defeats',
#  'defender',
#  'deference',
#  'deft',
#  'delectable',
#  'delicacy',
#  'delicate',
#  'delicious',
#  'delight',
#  'delighted',
#  'delightful',
#  'delightfully',
#  'dependable',
#  'dependably',
#  'deservedly',
#  'deserving',
#  'desirable',
#  'desiring',
#  'destiny',
#  'detachable',
#  'devout',
#  'dexterous',
#  'dextrous',
#  'dignified',
#  'dignity',
#  'diligence',
#  'diligent',
#  'diligently',
#  'diplomatic',
#  'dirt-cheap',
#  'distinction',
#  'distinctive',
#  'distinguished',
#  'diversified',
#  'divine',
#  'dominate',
#  'dominated',
#  'dominates',
#  'doubtless',
#  'dreamland',
#  'dumbfounded',
#  'dummy-proof',
#  'durable',
#  'dynamic',
#  'eager',
#  'eagerly',
#  'eagerness',
#  'earnest',
#  'earnestly',
#  'ease',
#  'eased',
#  'eases',
#  'easier',
#  'easiest',
#  'easiness',
#  'easing',
#  'easy',
#  'easy-to-use',
#  'easygoing',
#  'ebullience',
#  'economical',
#  'ecstasy',
#  'ecstatic',
#  'ecstatically',
#  'educated',
#  'effective',
#  'effectively',
#  'effectiveness',
#  'efficient',
#  'efficiently',
#  'effortless',
#  'effortlessly',
#  'effusion',
#  'effusive',
#  'elan',
#  'elated',
#  'elation',
#  'elegance',
#  'elegant',
#  'elegantly',
#  'elevate',
#  'elite',
#  'eloquence',
#  'eloquent',
#  'eloquently',
#  'eminence',
#  'eminent',
#  'empathize',
#  'empathy',
#  'empower',
#  'empowerment',
#  'enchanted',
#  'enchanting',
#  'encourage',
#  'encouragement',
#  'encouraging',
#  'endear',
#  'endearing',
#  'endorse',
#  'endorsed',
#  'endorsement',
#  'endorses',
#  'endorsing',
#  'energetic',
#  'energize',
#  'energy-efficient',
#  'energy-saving',
#  'engaging',
#  'engrossing',
#  'enhance',
#  'enhanced',
#  'enhancement',
#  'enhances',
#  'enjoy',
#  'enjoyable',
#  'enjoyably',
#  'enjoyed',
#  'enjoying',
#  'enjoyment',
#  'enjoys',
#  'enlighten',
#  'enlightenment',
#  'enough',
#  'enraptured',
#  'enrich',
#  'enrichment',
#  'enterprising',
#  'entertain',
#  'entertaining',
#  'entertains',
#  'enthralled',
#  'enthusiasm',
#  'enthusiast',
#  'enthusiastic',
#  'enthusiastically',
#  'entice',
#  'enticed',
#  'enticing',
#  'entranced',
#  'entrancing',
#  'entrust',
#  'enviable',
#  'envious',
#  'enviously',
#  'envy',
#  'equitable',
#  'ergonomical',
#  'ethical',
#  'euphoria',
#  'euphoric',
#  'evaluative',
#  'evenly',
#  'eventful',
#  'everlasting',
#  'evocative',
#  'exceed',
#  'exceeded',
#  'exceeding',
#  'exceedingly',
#  'exceeds',
#  'excel',
#  'excelent',
#  'excellant',
#  'excelled',
#  'excellence',
#  'excellency',
#  'excellent',
#  'excellently',
#  'excels',
#  'exceptional',
#  'exceptionally',
#  'excite',
#  'excited',
#  'excitedly',
#  'excitement',
#  'excites',
#  'exciting',
#  'exellent',
#  'exemplary',
#  'exhilarating',
#  'exhilaration',
#  'expansive',
#  'expeditiously',
#  'expertly',
#  'exquisite',
#  'exquisitely',
#  'extol',
#  'extoll',
#  'extraordinarily',
#  'extraordinary',
#  'exuberant',
#  'eye-catching',
#  'eyecatching',
#  'fabulous',
#  'fabulously',
#  'facilitate',
#  'fair',
#  'fairly',
#  'fairness',
#  'faith',
#  'faithful',
#  'faithfully',
#  'faithfulness',
#  'fame',
#  'famed',
#  'famous',
#  'famously',
#  'fancier',
#  'fancy',
#  'fanfare',
#  'fans',
#  'fantastic',
#  'fantastically',
#  'fascinate',
#  'fascinating',
#  'fascination',
#  'fashionable',
#  'fashionably',
#  'fast',
#  'fast-paced',
#  'faster',
#  'fastest',
#  'faultless',
#  'fav',
#  'fave',
#  'favor',
#  'favorable',
#  'favored',
#  'favorite',
#  'favour',
#  'fearless',
#  'feasible',
#  'feasibly',
#  'feat',
#  'feature-rich',
#  'feisty',
#  'fertile',
#  'fervent',
#  'fervently',
#  'fervor',
#  'festive',
#  'fidelity',
#  'fiery',
#  'fine',
#  'finely',
#  'finer',
#  'finest',
#  'firmer',
#  'first-class',
#  'first-rate',
#  'flashy',
#  'flatter',
#  'flattering',
#  'flawless',
#  'flawlessly',
#  'flexibility',
#  'flexible',
#  'flourish',
#  'flourishing',
#  'fluent',
#  'flutter',
#  'fond',
#  'fondly',
#  'fondness',
#  'foolproof',
#  'foremost',
#  'foresight',
#  'formidable',
#  'fortitude',
#  'fortuitous',
#  'fortuitously',
#  'fortunate',
#  'fortunately',
#  'fortune',
#  'free',
#  'freed',
#  'freedom',
#  'freedoms',
#  'fresh',
#  'fresher',
#  'freshest',
#  'friendliness',
#  'friendly',
#  'frolic',
#  'frugal',
#  'fruitful',
#  'ftw',
#  'fulfillment',
#  'fun',
#  'futuristic',
#  'gaiety',
#  'gain',
#  'gained',
#  'gaining',
#  'gains',
#  'gallant',
#  'galore',
#  'geeky',
#  'gem',
#  'gems',
#  'generosity',
#  'generous',
#  'generously',
#  'genial',
#  'genius',
#  'gentle',
#  'gentlest',
#  'genuine',
#  'gifted',
#  'glad',
#  'gladly',
#  'glamorous',
#  'glee',
#  'gleefully',
#  'glimmer',
#  'glimmering',
#  'glisten',
#  'glistening',
#  'glitter',
#  'glitz',
#  'glorify',
#  'glorious',
#  'gloriously',
#  'glory',
#  'glow',
#  'glowing',
#  'god-send',
#  'godlike',
#  'godsend',
#  'gold',
#  'golden',
#  'good',
#  'goodly',
#  'goodness',
#  'goodwill',
#  'goood',
#  'gooood',
#  'gorgeous',
#  'gorgeously',
#  'grace',
#  'graceful',
#  'gracefully',
#  'gracious',
#  'graciously',
#  'grand',
#  'grandeur',
#  'grateful',
#  'gratefully',
#  'gratification',
#  'gratified',
#  'gratifying',
#  'gratitude',
#  'great',
#  'greatest',
#  'greatness',
#  'grin',
#  'groundbreaking',
#  'guarantee',
#  'guidance',
#  'gumption',
#  'gush',
#  'gusto',
#  'gutsy',
#  'hail',
#  'hale',
#  'hallmark',
#  'hallmarks',
#  'hallowed',
#  'handier',
#  'handily',
#  'hands-down',
#  'handsome',
#  'handsomely',
#  'handy',
#  'happier',
#  'happily',
#  'happiness',
#  'happy',
#  'hard-working',
#  'hardier',
#  'hardy',
#  'harmless',
#  'harmonious',
#  'harmoniously',
#  'harmony',
#  'headway',
#  'heal',
#  'healthful',
#  'healthy',
#  'heartfelt',
#  'heartily',
#  'heartwarming',
#  'heaven',
#  'heavenly',
#  'helped',
#  'helpful',
#  'helping',
#  'hero',
#  'heroic',
#  'heroine',
#  'heros',
#  'high-quality',
#  'hilarious',
#  'holy',
#  'homage',
#  'honest',
#  'honesty',
#  'honor',
#  'honorable',
#  'honored',
#  'honoring',
#  'hooray',
#  'hopeful',
#  'hot',
#  'hotcakes',
#  'hottest',
#  'hug',
#  'humane',
#  'humble',
#  'humility',
#  'humor',
#  'humorous',
#  'humorously',
#  'humour',
#  'ideal',
#  'ideally',
#  'idol',
#  'idyllic',
#  'illuminate',
#  'illuminating',
#  'illustrious',
#  'imaginative',
#  'immaculate',
#  'immaculately',
#  'immense',
#  'impartial',
#  'impartiality',
#  'impartially',
#  'impeccable',
#  'impeccably',
#  'important',
#  'impress',
#  'impressed',
#  'impresses',
#  'impressive',
#  'impressively',
#  'improve',
#  'improved',
#  'improvement',
#  'improvements',
#  'improves',
#  'improving',
#  'incredible',
#  'incredibly',
#  'indebted',
#  'individualized',
#  'indulgence',
#  'indulgent',
#  'industrious',
#  'inexpensive',
#  'infallible',
#  'influential',
#  'ingenious',
#  'ingeniously',
#  'ingenuity',
#  'ingenuous',
#  'innocuous',
#  'innovation',
#  'innovative',
#  'inpressed',
#  'insightful',
#  'inspiration',
#  'inspirational',
#  'inspire',
#  'inspiring',
#  'instantly',
#  'instructive',
#  'instrumental',
#  'integral',
#  'integrated',
#  'intelligence',
#  'intelligent',
#  'intelligible',
#  'interesting',
#  'interests',
#  'intimacy',
#  'intimate',
#  'intricate',
#  'intrigue',
#  'intriguing',
#  'intuitive',
#  'invaluable',
#  'inventive',
#  'invigorating',
#  'invincible',
#  'invulnerable',
#  'irreplaceable',
#  'irresistible',
#  'issue-free',
#  'jaw-dropping',
#  'jolly',
#  'joy',
#  'joyful',
#  'joyfully',
#  'joyous',
#  'judicious',
#  'justly',
#  'keen',
#  'keenly',
#  'kid-friendly',
#  'kindly',
#  'kindness',
#  'knowledgeable',
#  'kudos',
#  'large-capacity',
#  'laud',
#  'laudable',
#  'lavish',
#  'law-abiding',
#  'lawful',
#  'lead',
#  'leading',
#  'leads',
#  'lean',
#  'led',
#  'legendary',
#  'leverage',
#  'liberate',
#  'liberation',
#  'liberty',
#  'lifesaver',
#  'lighter',
#  'likable',
#  'like',
#  'liked',
#  'likes',
#  'liking',
#  'lively',
#  'logical',
#  'long-lasting',
#  'lovable',
#  'love',
#  'loved',
#  'lovely',
#  'lover',
#  'loves',
#  'loving',
#  'low-cost',
#  'low-price',
#  'low-priced',
#  'low-risk',
#  'lower-priced',
#  'loyal',
#  'loyalty',
#  'lucid',
#  'luck',
#  'luckier',
#  'luckiest',
#  'lucky',
#  'lucrative',
#  'luminous',
#  'lush',
#  'luster',
#  'lustrous',
#  'luxuriant',
#  'luxurious',
#  'luxuriously',
#  'luxury',
#  'lyrical',
#  'magic',
#  'magical',
#  'magnificence',
#  'magnificent',
#  'magnificently',
#  'majestic',
#  'majesty',
#  'manageable',
#  'maneuverable',
#  'marvel',
#  'marveled',
#  'marvelled',
#  'marvellous',
#  'marvelous',
#  'marvelously',
#  'marvels',
#  'master',
#  'masterful',
#  'masterfully',
#  'masterpiece',
#  'masterpieces',
#  'masters',
#  'mastery',
#  'matchless',
#  'mature',
#  'maturity',
#  'meaningful',
#  'memorable',
#  'merciful',
#  'mercifully',
#  'mercy',
#  'merit',
#  'merrily',
#  'merry',
#  'mesmerize',
#  'mesmerized',
#  'mesmerizing',
#  'meticulous',
#  'meticulously',
#  'mightily',
#  'mighty',
#  'mind-blowing',
#  'miracle',
#  'miracles',
#  'miraculous',
#  'miraculously',
#  'modern',
#  'modest',
#  'modesty',
#  'momentous',
#  'monumental',
#  'monumentally',
#  'morality',
#  'motivated',
#  'multi-purpose',
#  'navigable',
#  'neat',
#  'neatest',
#  'neatly',
#  'nice',
#  'nicely',
#  'nicer',
#  'nicest',
#  'nifty',
#  'nimble',
#  'noble',
#  'noiseless',
#  'non-violent',
#  'notably',
#  'noteworthy',
#  'nourishment',
#  'novelty',
#  'nurturing',
#  'oasis',
#  'obsession',
#  'obtainable',
#  'openly',
#  'openness',
#  'optimal',
#  'optimism',
#  'optimistic',
#  'opulent',
#  'orderly',
#  'originality',
#  'outdo',
#  'outdone',
#  'outperform',
#  'outperformed',
#  'outperforming',
#  'outperforms',
#  'outshine',
#  'outshone',
#  'outsmart',
#  'outstanding',
#  'outstandingly',
#  ...]

# %%
new_bilingiu['polarity'].value_counts()
# Out:
# negative    3362
# positive    1649
# Name: polarity, dtype: int64

# %%
from gensim.test.utils import datapath
from gensim import utils
def get_data():
    sentences = []
    data = 'assignment_4_files/english.txt'
    for line in open(data):
        sentences.append(utils.simple_preprocess(line))
    return sentences

# %%
import gensim.models
sentences = get_data()

# %%
model = gensim.models.Word2Vec(sentences=sentences,min_count=1,workers=6,window=5,size=700,negative=15,iter=20)

# %%
model.wv['good'].shape
# Out:
# (700,)

# %%
len(model.wv.vocab)
# Out:
# 5887

# %%
model.similar_by_word("good")
# Out:
# /home/venktesh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similar_by_word` (Method will be removed in 4.0.0, use self.wv.similar_by_word() instead).
#   """Entry point for launching an IPython kernel.
# [('nice', 0.9368177056312561),
#  ('directory', 0.8905929327011108),
#  ('pretty', 0.8848155736923218),
#  ('ok', 0.8823883533477783),
#  ('friendly', 0.871130108833313),
#  ('ambience', 0.8710258603096008),
#  ('great', 0.866337776184082),
#  ('slow', 0.8561553955078125),
#  ('fresh', 0.8536471128463745),
#  ('reasonable', 0.8481967449188232)]

# %%
def get_hindi_data():
    sentences = []
    data = 'assignment_4_files/hindi.txt'
    for line in open(data):
        sentences.append(utils.simple_preprocess(line))
    return sentences

# %%
hindi_sent = get_hindi_data()

hindi_word2vec_model = gensim.models.Word2Vec(sentences=hindi_sent,min_count=1,workers=6,window=5,size=700,negative=15,iter=20)

# %%
hindi_word2vec_model.wv.vocab
# Out:
# {'सब': <gensim.models.keyedvectors.Vocab at 0x7f69ac18d750>,
#  'कअप': <gensim.models.keyedvectors.Vocab at 0x7f69ac18d5d0>,
#  'चर': <gensim.models.keyedvectors.Vocab at 0x7f69ac18d650>,
#  'पअप': <gensim.models.keyedvectors.Vocab at 0x7f69ac18d7d0>,
#  'तरह': <gensim.models.keyedvectors.Vocab at 0x7f69ac18d950>,
#  'जर': <gensim.models.keyedvectors.Vocab at 0x7f69ac18da90>,
#  'इस': <gensim.models.keyedvectors.Vocab at 0x7f69ac18db10>,
#  'सवर': <gensim.models.keyedvectors.Vocab at 0x7f69ac18db90>,
#  'करन': <gensim.models.keyedvectors.Vocab at 0x7f69ac18d8d0>,
#  'गइन': <gensim.models.keyedvectors.Vocab at 0x7f69ac18d9d0>,
#  'अलर': <gensim.models.keyedvectors.Vocab at 0x7f69ac18dc10>,
#  'और': <gensim.models.keyedvectors.Vocab at 0x7f69ac18dc90>,
#  'शन': <gensim.models.keyedvectors.Vocab at 0x7f69ac18dd10>,
#  'ऑप': <gensim.models.keyedvectors.Vocab at 0x7f69ac18dd90>,
#  'अब': <gensim.models.keyedvectors.Vocab at 0x7f69ac18de10>,
#  'नए': <gensim.models.keyedvectors.Vocab at 0x7f69ac18de90>,
#  'गलत': <gensim.models.keyedvectors.Vocab at 0x7f69ac18df10>,
#  'नह': <gensim.models.keyedvectors.Vocab at 0x7f69ac18df90>,
#  'अक': <gensim.models.keyedvectors.Vocab at 0x7f69ac18d450>,
#  'हद': <gensim.models.keyedvectors.Vocab at 0x7f69ac18d350>,
#  'एग': <gensim.models.keyedvectors.Vocab at 0x7f69ac18d2d0>,
#  'twitter': <gensim.models.keyedvectors.Vocab at 0x7f69ac18d1d0>,
#  'periscope': <gensim.models.keyedvectors.Vocab at 0x7f69ac18d0d0>,
#  'app': <gensim.models.keyedvectors.Vocab at 0x7f69ac18d050>,
#  'यड': <gensim.models.keyedvectors.Vocab at 0x7f69ac18e050>,
#  'टक': <gensim.models.keyedvectors.Vocab at 0x7f69ac18e0d0>,
#  'उसस': <gensim.models.keyedvectors.Vocab at 0x7f69ac18e150>,
#  'ऊपर': <gensim.models.keyedvectors.Vocab at 0x7f69ac18e1d0>,
#  'वर': <gensim.models.keyedvectors.Vocab at 0x7f69ac18e310>,
#  'जन': <gensim.models.keyedvectors.Vocab at 0x7f69ac18e3d0>,
#  'पर': <gensim.models.keyedvectors.Vocab at 0x7f69ac18e250>,
#  'करत': <gensim.models.keyedvectors.Vocab at 0x7f69ac18e350>,
#  'एप': <gensim.models.keyedvectors.Vocab at 0x7f69ac18e4d0>,
#  'गय': <gensim.models.keyedvectors.Vocab at 0x7f69ac18e450>,
#  'बह': <gensim.models.keyedvectors.Vocab at 0x7f69ac18e550>,
#  'तहत': <gensim.models.keyedvectors.Vocab at 0x7f69ac18e5d0>,
#  'डक': <gensim.models.keyedvectors.Vocab at 0x7f69ac18e6d0>,
#  'कन': <gensim.models.keyedvectors.Vocab at 0x7f69ac18e710>,
#  'वह': <gensim.models.keyedvectors.Vocab at 0x7f69ac18e750>,
#  'सकत': <gensim.models.keyedvectors.Vocab at 0x7f69ac18e810>,
#  'जह': <gensim.models.keyedvectors.Vocab at 0x7f69ac18e890>,
#  'टर': <gensim.models.keyedvectors.Vocab at 0x7f69ac18e950>,
#  'इम': <gensim.models.keyedvectors.Vocab at 0x7f69ac18e990>,
#  'इल': <gensim.models.keyedvectors.Vocab at 0x7f69ac18ea10>,
#  'बचत': <gensim.models.keyedvectors.Vocab at 0x7f69ac18ea90>,
#  'आपक': <gensim.models.keyedvectors.Vocab at 0x7f69ac18eb90>,
#  'टफ': <gensim.models.keyedvectors.Vocab at 0x7f69ac18eb10>,
#  'तर': <gensim.models.keyedvectors.Vocab at 0x7f69ac18ec10>,
#  'ऎस': <gensim.models.keyedvectors.Vocab at 0x7f69ac18ec90>,
#  'नस': <gensim.models.keyedvectors.Vocab at 0x7f69ac18ed50>,
#  'अपन': <gensim.models.keyedvectors.Vocab at 0x7f69ac18ed90>,
#  'खर': <gensim.models.keyedvectors.Vocab at 0x7f69ac18ee10>,
#  'कर': <gensim.models.keyedvectors.Vocab at 0x7f69ac18ef10>,
#  'एक': <gensim.models.keyedvectors.Vocab at 0x7f69ac18ef50>,
#  'सम': <gensim.models.keyedvectors.Vocab at 0x7f69ac18ef90>,
#  'वल': <gensim.models.keyedvectors.Vocab at 0x7f69ac190050>,
#  'बल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1900d0>,
#  'पन': <gensim.models.keyedvectors.Vocab at 0x7f69ac190150>,
#  'सप': <gensim.models.keyedvectors.Vocab at 0x7f69ac1901d0>,
#  'आर': <gensim.models.keyedvectors.Vocab at 0x7f69ac190250>,
#  'लन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1902d0>,
#  'यक': <gensim.models.keyedvectors.Vocab at 0x7f69ac190350>,
#  'ओएस': <gensim.models.keyedvectors.Vocab at 0x7f69ac190410>,
#  'कब': <gensim.models.keyedvectors.Vocab at 0x7f69ac190450>,
#  'अन': <gensim.models.keyedvectors.Vocab at 0x7f69ac190510>,
#  'भव': <gensim.models.keyedvectors.Vocab at 0x7f69ac190590>,
#  'एम': <gensim.models.keyedvectors.Vocab at 0x7f69ac190650>,
#  'उपय': <gensim.models.keyedvectors.Vocab at 0x7f69ac190690>,
#  'यह': <gensim.models.keyedvectors.Vocab at 0x7f69ac190750>,
#  'ऐस': <gensim.models.keyedvectors.Vocab at 0x7f69ac190790>,
#  'सक': <gensim.models.keyedvectors.Vocab at 0x7f69ac190810>,
#  'समझन': <gensim.models.keyedvectors.Vocab at 0x7f69ac190890>,
#  'रत': <gensim.models.keyedvectors.Vocab at 0x7f69ac190910>,
#  'इसक': <gensim.models.keyedvectors.Vocab at 0x7f69ac190990>,
#  'अध': <gensim.models.keyedvectors.Vocab at 0x7f69ac190a10>,
#  'कतर': <gensim.models.keyedvectors.Vocab at 0x7f69ac190a90>,
#  'सह': <gensim.models.keyedvectors.Vocab at 0x7f69ac190b10>,
#  'डर': <gensim.models.keyedvectors.Vocab at 0x7f69ac190b90>,
#  'खत': <gensim.models.keyedvectors.Vocab at 0x7f69ac190c10>,
#  'इड': <gensim.models.keyedvectors.Vocab at 0x7f69ac190c90>,
#  'इप': <gensim.models.keyedvectors.Vocab at 0x7f69ac190d90>,
#  'यश': <gensim.models.keyedvectors.Vocab at 0x7f69ac190e90>,
#  'बढ': <gensim.models.keyedvectors.Vocab at 0x7f69ac190e10>,
#  'बन': <gensim.models.keyedvectors.Vocab at 0x7f69ac190f10>,
#  'रखन': <gensim.models.keyedvectors.Vocab at 0x7f69ac190f90>,
#  'आसम': <gensim.models.keyedvectors.Vocab at 0x7f69ac193050>,
#  'सफ': <gensim.models.keyedvectors.Vocab at 0x7f69ac1930d0>,
#  'रण': <gensim.models.keyedvectors.Vocab at 0x7f69ac193150>,
#  'अल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1931d0>,
#  'एल': <gensim.models.keyedvectors.Vocab at 0x7f69ac193250>,
#  'उपलब': <gensim.models.keyedvectors.Vocab at 0x7f69ac1932d0>,
#  'इट': <gensim.models.keyedvectors.Vocab at 0x7f69ac193350>,
#  'थम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1933d0>,
#  'लह': <gensim.models.keyedvectors.Vocab at 0x7f69ac193450>,
#  'इसम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1934d0>,
#  'यस': <gensim.models.keyedvectors.Vocab at 0x7f69ac193550>,
#  'अच': <gensim.models.keyedvectors.Vocab at 0x7f69ac1935d0>,
#  'समय': <gensim.models.keyedvectors.Vocab at 0x7f69ac193650>,
#  'सर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1936d0>,
#  'यर': <gensim.models.keyedvectors.Vocab at 0x7f69ac193750>,
#  'इडर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1937d0>,
#  'रय': <gensim.models.keyedvectors.Vocab at 0x7f69ac193850>,
#  'रभ': <gensim.models.keyedvectors.Vocab at 0x7f69ac1938d0>,
#  'वश': <gensim.models.keyedvectors.Vocab at 0x7f69ac1939d0>,
#  'अभ': <gensim.models.keyedvectors.Vocab at 0x7f69ac193950>,
#  'तक': <gensim.models.keyedvectors.Vocab at 0x7f69ac193ad0>,
#  'टरन': <gensim.models.keyedvectors.Vocab at 0x7f69ac193a50>,
#  'भर': <gensim.models.keyedvectors.Vocab at 0x7f69ac193b50>,
#  'हर': <gensim.models.keyedvectors.Vocab at 0x7f69ac193bd0>,
#  'नल': <gensim.models.keyedvectors.Vocab at 0x7f69ac193c50>,
#  'टरफ': <gensim.models.keyedvectors.Vocab at 0x7f69ac193cd0>,
#  'चक': <gensim.models.keyedvectors.Vocab at 0x7f69ac193dd0>,
#  'लटर': <gensim.models.keyedvectors.Vocab at 0x7f69ac193d50>,
#  'कलर': <gensim.models.keyedvectors.Vocab at 0x7f69ac193e50>,
#  'कम': <gensim.models.keyedvectors.Vocab at 0x7f69ac193f50>,
#  'एयरट': <gensim.models.keyedvectors.Vocab at 0x7f69ac193ed0>,
#  'दर': <gensim.models.keyedvectors.Vocab at 0x7f69ac193fd0>,
#  'डम': <gensim.models.keyedvectors.Vocab at 0x7f69ac195110>,
#  'लगत': <gensim.models.keyedvectors.Vocab at 0x7f69ac195090>,
#  'हल': <gensim.models.keyedvectors.Vocab at 0x7f69ac195210>,
#  'चमक': <gensim.models.keyedvectors.Vocab at 0x7f69ac195190>,
#  'एवर': <gensim.models.keyedvectors.Vocab at 0x7f69ac195290>,
#  'इव': <gensim.models.keyedvectors.Vocab at 0x7f69ac195350>,
#  'उसक': <gensim.models.keyedvectors.Vocab at 0x7f69ac195390>,
#  'गत': <gensim.models.keyedvectors.Vocab at 0x7f69ac195410>,
#  'बत': <gensim.models.keyedvectors.Vocab at 0x7f69ac195490>,
#  'रह': <gensim.models.keyedvectors.Vocab at 0x7f69ac195590>,
#  'एमब': <gensim.models.keyedvectors.Vocab at 0x7f69ac195650>,
#  'एस': <gensim.models.keyedvectors.Vocab at 0x7f69ac195510>,
#  'इफ': <gensim.models.keyedvectors.Vocab at 0x7f69ac1956d0>,
#  'ऑन': <gensim.models.keyedvectors.Vocab at 0x7f69ac195750>,
#  'इन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1957d0>,
#  'अलग': <gensim.models.keyedvectors.Vocab at 0x7f69ac195850>,
#  'इब': <gensim.models.keyedvectors.Vocab at 0x7f69ac1958d0>,
#  'गफ': <gensim.models.keyedvectors.Vocab at 0x7f69ac195950>,
#  'सबस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1959d0>,
#  'अत': <gensim.models.keyedvectors.Vocab at 0x7f69ac195a50>,
#  'पय': <gensim.models.keyedvectors.Vocab at 0x7f69ac195ad0>,
#  'नद': <gensim.models.keyedvectors.Vocab at 0x7f69ac195b50>,
#  'खन': <gensim.models.keyedvectors.Vocab at 0x7f69ac195bd0>,
#  'कल': <gensim.models.keyedvectors.Vocab at 0x7f69ac195c50>,
#  'ईज': <gensim.models.keyedvectors.Vocab at 0x7f69ac195cd0>,
#  'टल': <gensim.models.keyedvectors.Vocab at 0x7f69ac195d50>,
#  'सकन': <gensim.models.keyedvectors.Vocab at 0x7f69ac195dd0>,
#  'आज': <gensim.models.keyedvectors.Vocab at 0x7f69ac195e50>,
#  'हस': <gensim.models.keyedvectors.Vocab at 0x7f69ac195ed0>,
#  'षर': <gensim.models.keyedvectors.Vocab at 0x7f69ac195f50>,
#  'बड़': <gensim.models.keyedvectors.Vocab at 0x7f69ac195fd0>,
#  'नई': <gensim.models.keyedvectors.Vocab at 0x7f69ac197090>,
#  'तन': <gensim.models.keyedvectors.Vocab at 0x7f69ac197110>,
#  'आस': <gensim.models.keyedvectors.Vocab at 0x7f69ac197210>,
#  'रम': <gensim.models.keyedvectors.Vocab at 0x7f69ac197290>,
#  'कहन': <gensim.models.keyedvectors.Vocab at 0x7f69ac197150>,
#  'उतन': <gensim.models.keyedvectors.Vocab at 0x7f69ac197310>,
#  'आईफ': <gensim.models.keyedvectors.Vocab at 0x7f69ac197390>,
#  'उपभ': <gensim.models.keyedvectors.Vocab at 0x7f69ac197410>,
#  'इसल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1974d0>,
#  'उपकरण': <gensim.models.keyedvectors.Vocab at 0x7f69ac197510>,
#  'जगह': <gensim.models.keyedvectors.Vocab at 0x7f69ac197590>,
#  'रदर': <gensim.models.keyedvectors.Vocab at 0x7f69ac197650>,
#  'शक': <gensim.models.keyedvectors.Vocab at 0x7f69ac197690>,
#  'डव': <gensim.models.keyedvectors.Vocab at 0x7f69ac197710>,
#  'एयरब': <gensim.models.keyedvectors.Vocab at 0x7f69ac197790>,
#  'आल': <gensim.models.keyedvectors.Vocab at 0x7f69ac197810>,
#  'एर': <gensim.models.keyedvectors.Vocab at 0x7f69ac197890>,
#  'कड': <gensim.models.keyedvectors.Vocab at 0x7f69ac197910>,
#  'उन': <gensim.models.keyedvectors.Vocab at 0x7f69ac197990>,
#  'पह': <gensim.models.keyedvectors.Vocab at 0x7f69ac197a10>,
#  'सड': <gensim.models.keyedvectors.Vocab at 0x7f69ac197a90>,
#  'चल': <gensim.models.keyedvectors.Vocab at 0x7f69ac197b10>,
#  'वरअप': <gensim.models.keyedvectors.Vocab at 0x7f69ac197b90>,
#  'लत': <gensim.models.keyedvectors.Vocab at 0x7f69ac197c10>,
#  'उच': <gensim.models.keyedvectors.Vocab at 0x7f69ac197c90>,
#  'आकर': <gensim.models.keyedvectors.Vocab at 0x7f69ac197d10>,
#  'आप': <gensim.models.keyedvectors.Vocab at 0x7f69ac197dd0>,
#  'टवर': <gensim.models.keyedvectors.Vocab at 0x7f69ac197e10>,
#  'रक': <gensim.models.keyedvectors.Vocab at 0x7f69ac197f10>,
#  'हतर': <gensim.models.keyedvectors.Vocab at 0x7f69ac197f90>,
#  'तस': <gensim.models.keyedvectors.Vocab at 0x7f69ac198050>,
#  'आवश': <gensim.models.keyedvectors.Vocab at 0x7f69ac1980d0>,
#  'यकत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1981d0>,
#  'शनल': <gensim.models.keyedvectors.Vocab at 0x7f69ac198150>,
#  'उनक': <gensim.models.keyedvectors.Vocab at 0x7f69ac198250>,
#  'अर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1982d0>,
#  'उस': <gensim.models.keyedvectors.Vocab at 0x7f69ac198350>,
#  'बढ़': <gensim.models.keyedvectors.Vocab at 0x7f69ac198450>,
#  'मन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1983d0>,
#  'जक': <gensim.models.keyedvectors.Vocab at 0x7f69ac1984d0>,
#  'ऐप': <gensim.models.keyedvectors.Vocab at 0x7f69ac1986d0>,
#  'यत': <gensim.models.keyedvectors.Vocab at 0x7f69ac198550>,
#  'वस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1985d0>,
#  'रख': <gensim.models.keyedvectors.Vocab at 0x7f69ac198650>,
#  'रकत': <gensim.models.keyedvectors.Vocab at 0x7f69ac198750>,
#  'imdb': <gensim.models.keyedvectors.Vocab at 0x7f69ac1987d0>,
#  'हम': <gensim.models.keyedvectors.Vocab at 0x7f69ac198890>,
#  'अगर': <gensim.models.keyedvectors.Vocab at 0x7f69ac198910>,
#  'आपन': <gensim.models.keyedvectors.Vocab at 0x7f69ac198a10>,
#  'लम': <gensim.models.keyedvectors.Vocab at 0x7f69ac198b10>,
#  'अप': <gensim.models.keyedvectors.Vocab at 0x7f69ac198990>,
#  'टफ़': <gensim.models.keyedvectors.Vocab at 0x7f69ac198a90>,
#  'आसन': <gensim.models.keyedvectors.Vocab at 0x7f69ac198b90>,
#  'पस': <gensim.models.keyedvectors.Vocab at 0x7f69ac198c90>,
#  'ढन': <gensim.models.keyedvectors.Vocab at 0x7f69ac198c10>,
#  'यम': <gensim.models.keyedvectors.Vocab at 0x7f69ac198d50>,
#  'उनल': <gensim.models.keyedvectors.Vocab at 0x7f69ac198e10>,
#  'ईड': <gensim.models.keyedvectors.Vocab at 0x7f69ac198ed0>,
#  'आन': <gensim.models.keyedvectors.Vocab at 0x7f69ac198f10>,
#  'महत': <gensim.models.keyedvectors.Vocab at 0x7f69ac198f90>,
#  'उठ': <gensim.models.keyedvectors.Vocab at 0x7f69ac19b050>,
#  'इसपर': <gensim.models.keyedvectors.Vocab at 0x7f69ac19b0d0>,
#  'अद': <gensim.models.keyedvectors.Vocab at 0x7f69ac19b150>,
#  'खबर': <gensim.models.keyedvectors.Vocab at 0x7f69ac19b210>,
#  'पहल': <gensim.models.keyedvectors.Vocab at 0x7f69ac19b250>,
#  'रस': <gensim.models.keyedvectors.Vocab at 0x7f69ac19b2d0>,
#  'सएप': <gensim.models.keyedvectors.Vocab at 0x7f69ac19b350>,
#  'करण': <gensim.models.keyedvectors.Vocab at 0x7f69ac19b3d0>,
#  'आरम': <gensim.models.keyedvectors.Vocab at 0x7f69ac19b450>,
#  'बटन': <gensim.models.keyedvectors.Vocab at 0x7f69ac19b4d0>,
#  'तरफ': <gensim.models.keyedvectors.Vocab at 0x7f69ac19b550>,
#  'bbm': <gensim.models.keyedvectors.Vocab at 0x7f69ac19b610>,
#  'version': <gensim.models.keyedvectors.Vocab at 0x7f69ac19b690>,
#  'नय': <gensim.models.keyedvectors.Vocab at 0x7f69ac19b710>,
#  'voice': <gensim.models.keyedvectors.Vocab at 0x7f69ac19b750>,
#  'सस': <gensim.models.keyedvectors.Vocab at 0x7f69ac19b810>,
#  'ईफ': <gensim.models.keyedvectors.Vocab at 0x7f69ac19b890>,
#  'wifi': <gensim.models.keyedvectors.Vocab at 0x7f69ac19b8d0>,
#  'टस': <gensim.models.keyedvectors.Vocab at 0x7f69ac19b950>,
#  'लव': <gensim.models.keyedvectors.Vocab at 0x7f69ac19bad0>,
#  'rail': <gensim.models.keyedvectors.Vocab at 0x7f69ac19ba50>,
#  'radar': <gensim.models.keyedvectors.Vocab at 0x7f69ac19b990>,
#  'गल': <gensim.models.keyedvectors.Vocab at 0x7f69ac19bb50>,
#  'google': <gensim.models.keyedvectors.Vocab at 0x7f69ac19bbd0>,
#  'maps': <gensim.models.keyedvectors.Vocab at 0x7f69ac19bc50>,
#  'चलत': <gensim.models.keyedvectors.Vocab at 0x7f69ac19bd10>,
#  'बड': <gensim.models.keyedvectors.Vocab at 0x7f69ac19bd50>,
#  'मतलब': <gensim.models.keyedvectors.Vocab at 0x7f69ac19bdd0>,
#  'यन': <gensim.models.keyedvectors.Vocab at 0x7f69ac19be50>,
#  'चन': <gensim.models.keyedvectors.Vocab at 0x7f69ac19bf10>,
#  'मल': <gensim.models.keyedvectors.Vocab at 0x7f69ac19bf50>,
#  'पल': <gensim.models.keyedvectors.Vocab at 0x7f69ac19bfd0>,
#  'goggle': <gensim.models.keyedvectors.Vocab at 0x7f69ac19d090>,
#  'drive': <gensim.models.keyedvectors.Vocab at 0x7f69ac19d110>,
#  'application': <gensim.models.keyedvectors.Vocab at 0x7f69ac19d190>,
#  'कशन': <gensim.models.keyedvectors.Vocab at 0x7f69ac19d210>,
#  'डश': <gensim.models.keyedvectors.Vocab at 0x7f69ac19d290>,
#  'दन': <gensim.models.keyedvectors.Vocab at 0x7f69ac19d390>,
#  'अपग': <gensim.models.keyedvectors.Vocab at 0x7f69ac19d350>,
#  'जबक': <gensim.models.keyedvectors.Vocab at 0x7f69ac19d450>,
#  'document': <gensim.models.keyedvectors.Vocab at 0x7f69ac19d490>,
#  'आईक': <gensim.models.keyedvectors.Vocab at 0x7f69ac19d590>,
#  'सहज': <gensim.models.keyedvectors.Vocab at 0x7f69ac19d510>,
#  'धन': <gensim.models.keyedvectors.Vocab at 0x7f69ac19d610>,
#  'बदल': <gensim.models.keyedvectors.Vocab at 0x7f69ac19d690>,
#  'मज': <gensim.models.keyedvectors.Vocab at 0x7f69ac19d710>,
#  'ऑफ': <gensim.models.keyedvectors.Vocab at 0x7f69ac19d790>,
#  'ऑपशन': <gensim.models.keyedvectors.Vocab at 0x7f69ac19d810>,
#  'नन': <gensim.models.keyedvectors.Vocab at 0x7f69ac19d890>,
#  'दरअसल': <gensim.models.keyedvectors.Vocab at 0x7f69ac19d910>,
#  'तरर': <gensim.models.keyedvectors.Vocab at 0x7f69ac19da50>,
#  'टअप': <gensim.models.keyedvectors.Vocab at 0x7f69ac19dad0>,
#  'आत': <gensim.models.keyedvectors.Vocab at 0x7f69ac19db50>,
#  'ऑफब': <gensim.models.keyedvectors.Vocab at 0x7f69ac19dbd0>,
#  'नतम': <gensim.models.keyedvectors.Vocab at 0x7f69ac19d9d0>,
#  'पड': <gensim.models.keyedvectors.Vocab at 0x7f69ac19dc50>,
#  'परफ': <gensim.models.keyedvectors.Vocab at 0x7f69ac19ddd0>,
#  'आरप': <gensim.models.keyedvectors.Vocab at 0x7f69ac19dcd0>,
#  'लर': <gensim.models.keyedvectors.Vocab at 0x7f69ac19dd50>,
#  'चलन': <gensim.models.keyedvectors.Vocab at 0x7f69ac19ded0>,
#  'वक': <gensim.models.keyedvectors.Vocab at 0x7f69ac19de50>,
#  'महस': <gensim.models.keyedvectors.Vocab at 0x7f69ac19df50>,
#  'मरत': <gensim.models.keyedvectors.Vocab at 0x7f69ac19dfd0>,
#  'कभ': <gensim.models.keyedvectors.Vocab at 0x7f69ac207d50>,
#  'ऑफल': <gensim.models.keyedvectors.Vocab at 0x7f69ac207390>,
#  'बर': <gensim.models.keyedvectors.Vocab at 0x7f69ac207950>,
#  'तथ': <gensim.models.keyedvectors.Vocab at 0x7f69ac207650>,
#  'रहत': <gensim.models.keyedvectors.Vocab at 0x7f69ac207c50>,
#  'आरएस': <gensim.models.keyedvectors.Vocab at 0x7f69ac2077d0>,
#  'लफ': <gensim.models.keyedvectors.Vocab at 0x7f69ac207bd0>,
#  'हत': <gensim.models.keyedvectors.Vocab at 0x7f69ac207ad0>,
#  'इतन': <gensim.models.keyedvectors.Vocab at 0x7f69ac207dd0>,
#  'रज': <gensim.models.keyedvectors.Vocab at 0x7f69ac207b90>,
#  'नक': <gensim.models.keyedvectors.Vocab at 0x7f69ac207cd0>,
#  'एव': <gensim.models.keyedvectors.Vocab at 0x7f69ac2079d0>,
#  'उजर': <gensim.models.keyedvectors.Vocab at 0x7f69ac207850>,
#  'वजन': <gensim.models.keyedvectors.Vocab at 0x7f69ac207a50>,
#  'ओप': <gensim.models.keyedvectors.Vocab at 0x7f69ac207210>,
#  'समस': <gensim.models.keyedvectors.Vocab at 0x7f69ac2078d0>,
#  'आउट': <gensim.models.keyedvectors.Vocab at 0x7f69ac207310>,
#  'इनब': <gensim.models.keyedvectors.Vocab at 0x7f69ac207090>,
#  'कट': <gensim.models.keyedvectors.Vocab at 0x7f69ac207290>,
#  'ईव': <gensim.models.keyedvectors.Vocab at 0x7f69ae7485d0>,
#  'आईआरस': <gensim.models.keyedvectors.Vocab at 0x7f69ae748d90>,
#  'बस': <gensim.models.keyedvectors.Vocab at 0x7f69ae748f10>,
#  'एसफ': <gensim.models.keyedvectors.Vocab at 0x7f69ae748ad0>,
#  'कई': <gensim.models.keyedvectors.Vocab at 0x7f69ae748190>,
#  'गए': <gensim.models.keyedvectors.Vocab at 0x7f69ae748f90>,
#  'औश': <gensim.models.keyedvectors.Vocab at 0x7f69ae748310>,
#  'यल': <gensim.models.keyedvectors.Vocab at 0x7f69ae7480d0>,
#  'जद': <gensim.models.keyedvectors.Vocab at 0x7f69ae748490>,
#  'सव': <gensim.models.keyedvectors.Vocab at 0x7f69af189290>,
#  'मजब': <gensim.models.keyedvectors.Vocab at 0x7f69af189210>,
#  'वट': <gensim.models.keyedvectors.Vocab at 0x7f69af189d50>,
#  'एफ': <gensim.models.keyedvectors.Vocab at 0x7f69af189f50>,
#  'आव': <gensim.models.keyedvectors.Vocab at 0x7f69af189cd0>,
#  'षक': <gensim.models.keyedvectors.Vocab at 0x7f69af189390>,
#  'एसएलआर': <gensim.models.keyedvectors.Vocab at 0x7f69af189bd0>,
#  'लगभग': <gensim.models.keyedvectors.Vocab at 0x7f69af189850>,
#  'शत': <gensim.models.keyedvectors.Vocab at 0x7f69af189690>,
#  'कवर': <gensim.models.keyedvectors.Vocab at 0x7f69af189a10>,
#  'इज': <gensim.models.keyedvectors.Vocab at 0x7f69ac00b6d0>,
#  'इनक': <gensim.models.keyedvectors.Vocab at 0x7f69ac00b9d0>,
#  'उलझन': <gensim.models.keyedvectors.Vocab at 0x7f69ac00b5d0>,
#  'एलस': <gensim.models.keyedvectors.Vocab at 0x7f69ac00b350>,
#  'रबर': <gensim.models.keyedvectors.Vocab at 0x7f69ac00b650>,
#  'मद': <gensim.models.keyedvectors.Vocab at 0x7f69ac00b8d0>,
#  'एमएएच': <gensim.models.keyedvectors.Vocab at 0x7f69ac00b0d0>,
#  'एए': <gensim.models.keyedvectors.Vocab at 0x7f69ac00b850>,
#  'भक': <gensim.models.keyedvectors.Vocab at 0x7f69ac00bad0>,
#  'नजर': <gensim.models.keyedvectors.Vocab at 0x7f69ac00b050>,
#  'इश': <gensim.models.keyedvectors.Vocab at 0x7f69ac00b3d0>,
#  'raw': <gensim.models.keyedvectors.Vocab at 0x7f69ac00bd50>,
#  'jpeg': <gensim.models.keyedvectors.Vocab at 0x7f69ac00b950>,
#  'तब': <gensim.models.keyedvectors.Vocab at 0x7f69ac00b250>,
#  'मर': <gensim.models.keyedvectors.Vocab at 0x7f69ac00b550>,
#  'ऑट': <gensim.models.keyedvectors.Vocab at 0x7f69ac00b4d0>,
#  'कस': <gensim.models.keyedvectors.Vocab at 0x7f69ac00b450>,
#  'एएफ': <gensim.models.keyedvectors.Vocab at 0x7f69ac00b2d0>,
#  'आइएसओ': <gensim.models.keyedvectors.Vocab at 0x7f69ac00b1d0>,
#  'iso': <gensim.models.keyedvectors.Vocab at 0x7f69ac00b150>,
#  'णवत': <gensim.models.keyedvectors.Vocab at 0x7f69ac089310>,
#  'इनम': <gensim.models.keyedvectors.Vocab at 0x7f69ac089c10>,
#  'धल': <gensim.models.keyedvectors.Vocab at 0x7f69ac089a90>,
#  'मत': <gensim.models.keyedvectors.Vocab at 0x7f69ac089b90>,
#  'एफप': <gensim.models.keyedvectors.Vocab at 0x7f69ac089910>,
#  'तव': <gensim.models.keyedvectors.Vocab at 0x7f69ac089690>,
#  'कह': <gensim.models.keyedvectors.Vocab at 0x7f69ac089e10>,
#  'मदद': <gensim.models.keyedvectors.Vocab at 0x7f69ac089d10>,
#  'सल': <gensim.models.keyedvectors.Vocab at 0x7f69ac089190>,
#  'एचड': <gensim.models.keyedvectors.Vocab at 0x7f69ac089110>,
#  'गई': <gensim.models.keyedvectors.Vocab at 0x7f69ac089c90>,
#  'डल': <gensim.models.keyedvectors.Vocab at 0x7f69ac089810>,
#  'आईएसओ': <gensim.models.keyedvectors.Vocab at 0x7f69ac089a10>,
#  'पए': <gensim.models.keyedvectors.Vocab at 0x7f69ac089710>,
#  'लग': <gensim.models.keyedvectors.Vocab at 0x7f69ac089490>,
#  'एमओएस': <gensim.models.keyedvectors.Vocab at 0x7f69ac089090>,
#  'ii': <gensim.models.keyedvectors.Vocab at 0x7f69ac089e90>,
#  'ईब': <gensim.models.keyedvectors.Vocab at 0x7f69ac089b10>,
#  'टम': <gensim.models.keyedvectors.Vocab at 0x7f69ac089390>,
#  'elph': <gensim.models.keyedvectors.Vocab at 0x7f69ac089210>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x7f69ac089d90>,
#  'पचर': <gensim.models.keyedvectors.Vocab at 0x7f69ac089f10>,
#  'nikon': <gensim.models.keyedvectors.Vocab at 0x7f69ac209490>,
#  'coolpix': <gensim.models.keyedvectors.Vocab at 0x7f69ac209450>,
#  'एमएम': <gensim.models.keyedvectors.Vocab at 0x7f69ac209610>,
#  'लवर': <gensim.models.keyedvectors.Vocab at 0x7f69ac209bd0>,
#  'एसएक': <gensim.models.keyedvectors.Vocab at 0x7f69ac209b50>,
#  'ऑपर': <gensim.models.keyedvectors.Vocab at 0x7f69ac083cd0>,
#  'टआउट': <gensim.models.keyedvectors.Vocab at 0x7f69ac083350>,
#  'फर': <gensim.models.keyedvectors.Vocab at 0x7f69ac083650>,
#  'इटन': <gensim.models.keyedvectors.Vocab at 0x7f69ac083a10>,
#  'एडजस': <gensim.models.keyedvectors.Vocab at 0x7f69ac083b90>,
#  'करक': <gensim.models.keyedvectors.Vocab at 0x7f69ac0837d0>,
#  'इमर': <gensim.models.keyedvectors.Vocab at 0x7f69ac083a90>,
#  'आय': <gensim.models.keyedvectors.Vocab at 0x7f69ac083e10>,
#  'इक': <gensim.models.keyedvectors.Vocab at 0x7f69ac083f90>,
#  'षम': <gensim.models.keyedvectors.Vocab at 0x7f69ac083b50>,
#  'लपअप': <gensim.models.keyedvectors.Vocab at 0x7f69ac083d90>,
#  'आए': <gensim.models.keyedvectors.Vocab at 0x7f69ac083990>,
#  'आग': <gensim.models.keyedvectors.Vocab at 0x7f69ac19f110>,
#  'यफ': <gensim.models.keyedvectors.Vocab at 0x7f69ac19f090>,
#  'आई': <gensim.models.keyedvectors.Vocab at 0x7f69ac19f190>,
#  'टय': <gensim.models.keyedvectors.Vocab at 0x7f69ac19f310>,
#  'सनल': <gensim.models.keyedvectors.Vocab at 0x7f69ac19f1d0>,
#  'घर': <gensim.models.keyedvectors.Vocab at 0x7f69ac19f290>,
#  'उत': <gensim.models.keyedvectors.Vocab at 0x7f69ac19f490>,
#  'यद': <gensim.models.keyedvectors.Vocab at 0x7f69ac19f390>,
#  'उद': <gensim.models.keyedvectors.Vocab at 0x7f69ac19f410>,
#  'बद': <gensim.models.keyedvectors.Vocab at 0x7f69ac19f510>,
#  'ओर': <gensim.models.keyedvectors.Vocab at 0x7f69ac19f590>,
#  'मम': <gensim.models.keyedvectors.Vocab at 0x7f69ac19f610>,
#  'एन': <gensim.models.keyedvectors.Vocab at 0x7f69ac19f690>,
#  'एड': <gensim.models.keyedvectors.Vocab at 0x7f69ac19f710>,
#  'ओएलईड': <gensim.models.keyedvectors.Vocab at 0x7f69ac19f790>,
#  'डरट': <gensim.models.keyedvectors.Vocab at 0x7f69ac19f890>,
#  'डईआईएसएस': <gensim.models.keyedvectors.Vocab at 0x7f69ac19f810>,
#  'इसस': <gensim.models.keyedvectors.Vocab at 0x7f69ac19f910>,
#  'उतरकर': <gensim.models.keyedvectors.Vocab at 0x7f69ac19f990>,
#  'गड': <gensim.models.keyedvectors.Vocab at 0x7f69ac19fa10>,
#  'एचट': <gensim.models.keyedvectors.Vocab at 0x7f69ac19fa90>,
#  'आरई': <gensim.models.keyedvectors.Vocab at 0x7f69ac19fb90>,
#  'एसड': <gensim.models.keyedvectors.Vocab at 0x7f69ac19fb10>,
#  'एमप': <gensim.models.keyedvectors.Vocab at 0x7f69ac19fc10>,
#  'टच': <gensim.models.keyedvectors.Vocab at 0x7f69ac19fc90>,
#  'एचस': <gensim.models.keyedvectors.Vocab at 0x7f69ac19fd10>,
#  'जव': <gensim.models.keyedvectors.Vocab at 0x7f69ac19fd90>,
#  'एच': <gensim.models.keyedvectors.Vocab at 0x7f69ac19fe10>,
#  'ईर': <gensim.models.keyedvectors.Vocab at 0x7f69ac19fe90>,
#  'आउटप': <gensim.models.keyedvectors.Vocab at 0x7f69ac19ff10>,
#  'एफआर': <gensim.models.keyedvectors.Vocab at 0x7f69ac19ff90>,
#  'इयर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a0050>,
#  'ऑड': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a00d0>,
#  'इएच': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a0150>,
#  'भवत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a01d0>,
#  'एण': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a03d0>,
#  'ऑरव': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a0250>,
#  'सट': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a02d0>,
#  'रखत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a0350>,
#  'इएम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a0450>,
#  'वन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a0550>,
#  'समझ': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a04d0>,
#  'रजर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a0650>,
#  'आइस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a05d0>,
#  'इवर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a0950>,
#  'सच': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a06d0>,
#  'डफ': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a0750>,
#  'अट': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a07d0>,
#  'जल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a0850>,
#  'दब': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a08d0>,
#  'सलर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a0a50>,
#  'शर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a09d0>,
#  'षण': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a0b50>,
#  'षणकर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a0c10>,
#  'वरफ': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a0c90>,
#  'गद': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a0d10>,
#  'उठकर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a0b90>,
#  'रहन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a0d90>,
#  'टन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a0e90>,
#  'एयर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a0f10>,
#  'मश': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a0e10>,
#  'रन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a0f90>,
#  'गरकर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a3050>,
#  'लकर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a3110>,
#  'आद': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a3190>,
#  'हज': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a3250>,
#  'तकन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a32d0>,
#  'खतर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a3350>,
#  'ऑनल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a31d0>,
#  'पक': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a33d0>,
#  'कहत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a3450>,
#  'दक': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a35d0>,
#  'एलज': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a34d0>,
#  'छन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a3550>,
#  'ऑडर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a36d0>,
#  'पम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a3750>,
#  'ac': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a3650>,
#  'षमत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a37d0>,
#  'कमर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a38d0>,
#  'खपत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a3850>,
#  'lcd': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a3950>,
#  'ghz': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a39d0>,
#  'arm': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a3a50>,
#  'gb': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a3ad0>,
#  'ddr': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a3b50>,
#  'mm': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a3c10>,
#  'गहर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a3c50>,
#  'पट': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a3d50>,
#  'एचप': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a3d90>,
#  'पव': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a3dd0>,
#  'dv': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a3e50>,
#  'टव': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a3f10>,
#  'इसकर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a3f50>,
#  'फल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a3fd0>,
#  'टज': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a5110>,
#  'असर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a5090>,
#  'कत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a5210>,
#  'करव': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a5290>,
#  'गरप': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a5310>,
#  'नर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a5390>,
#  'जनक': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a53d0>,
#  'चमकद': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a5450>,
#  'समर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a54d0>,
#  'hd': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a5510>,
#  'असतत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a5590>,
#  'nvidia': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a5610>,
#  'geforce': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a5690>,
#  'गर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a5710>,
#  'वहन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a5790>,
#  'चत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a5810>,
#  'कलत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a5890>,
#  'मक': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a5910>,
#  'षत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a5990>,
#  'hdmi': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a5a10>,
#  'इनप': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a5a90>,
#  'ढक': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a5b10>,
#  'सत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a5b90>,
#  'रव': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a5c10>,
#  'कनवर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a5d50>,
#  'आक': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a5cd0>,
#  'पतल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a5dd0>,
#  'एएमड': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a5e50>,
#  'आइड': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a5f50>,
#  'एकदम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a5ed0>,
#  'टब': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a5fd0>,
#  'छव': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a7090>,
#  'सज': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a7110>,
#  'छह': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a7190>,
#  'रहण': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a7210>,
#  'डड': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a7310>,
#  'इपर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a73d0>,
#  'एसब': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a7290>,
#  'एमआई': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a7410>,
#  'उलट': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a7490>,
#  'आध': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a7510>,
#  'कद': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a7590>,
#  'यरल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a7650>,
#  'इत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a7690>,
#  'मह': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a7710>,
#  'चम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a7790>,
#  'खड़': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a7810>,
#  'ज़र': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a7910>,
#  'आसप': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a7990>,
#  'डन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a7850>,
#  'रश': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a7a50>,
#  'ज़बरदस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a7b90>,
#  'मज़ब': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a7a90>,
#  'वम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a7b10>,
#  'वज़न': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a7c10>,
#  'नज़र': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a7c90>,
#  'एनव': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a7d10>,
#  'षजनक': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a7d90>,
#  'रद': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a7e10>,
#  'अनइनस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a7e90>,
#  'यवध': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a7f90>,
#  'उम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a7f10>,
#  'हमन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a8050>,
#  'मब': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a80d0>,
#  'टचप': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a81d0>,
#  'ज़गह': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a8250>,
#  'सभ': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a8110>,
#  'ज़व': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a82d0>,
#  'इज़': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a8350>,
#  'तम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a8450>,
#  'लक': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a83d0>,
#  'मददग': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a8550>,
#  'सफलत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a84d0>,
#  'कमज': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a85d0>,
#  'लचस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a8650>,
#  'मस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a8710>,
#  'आपर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a8750>,
#  'यरस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a87d0>,
#  'गम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a8850>,
#  'एपल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a8910>,
#  'एलईड': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a8950>,
#  'इटव': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a89d0>,
#  'रखकर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a8a50>,
#  'जनर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a8b10>,
#  'अथव': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a8b90>,
#  'लगव': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a8c10>,
#  'सबक': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a8c90>,
#  'पकड': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a8d10>,
#  'षकर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a8d90>,
#  'महज': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a8e10>,
#  'बक': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a8e90>,
#  'एट': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a8f10>,
#  'नट': <gensim.models.keyedvectors.Vocab at 0x7f69ac1a8f90>,
#  'थर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ab090>,
#  'ईथरन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ab0d0>,
#  'टचस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ab150>,
#  'पड़त': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ab1d0>,
#  'बजट': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ab250>,
#  'डय': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ab2d0>,
#  'एसव': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ab350>,
#  'एफएनब': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ab3d0>,
#  'आश': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ab450>,
#  'यजनक': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ab4d0>,
#  'टरनल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ab550>,
#  'ips': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ab5d0>,
#  'ssd': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ab690>,
#  'sata': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ab710>,
#  'gbit': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ab750>,
#  'ओब': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ab7d0>,
#  'सटर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ab890>,
#  'कप': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ab910>,
#  'ईट': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ab990>,
#  'एटम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1aba10>,
#  'hp': <gensim.models.keyedvectors.Vocab at 0x7f69ac1aba90>,
#  'इटब': <gensim.models.keyedvectors.Vocab at 0x7f69ac1abb10>,
#  'dts': <gensim.models.keyedvectors.Vocab at 0x7f69ac1abb90>,
#  'तय': <gensim.models.keyedvectors.Vocab at 0x7f69ac1abc10>,
#  'इफ़': <gensim.models.keyedvectors.Vocab at 0x7f69ac1abc90>,
#  'छल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1abd10>,
#  'अवत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1abd90>,
#  'सलत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1abe10>,
#  'ओम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1abe90>,
#  'गन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1abf10>,
#  'वग': <gensim.models.keyedvectors.Vocab at 0x7f69ac1abf90>,
#  'जब': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ad050>,
#  'ईम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ad0d0>,
#  'पढ': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ad150>,
#  'औसत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ad1d0>,
#  'अस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ad250>,
#  'लस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ad2d0>,
#  'गज': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ad350>,
#  'एचज': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ad3d0>,
#  'spice': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ad450>,
#  'stellar': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ad4d0>,
#  'horizon': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ad550>,
#  'mediatek': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ad5d0>,
#  'mb': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ad650>,
#  'ram': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ad6d0>,
#  'mah': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ad750>,
#  'असल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ad7d0>,
#  'अव': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ad8d0>,
#  'यवस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ad950>,
#  'एमट': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ad990>,
#  'mts': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ada50>,
#  'भरप': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ad9d0>,
#  'nokia': <gensim.models.keyedvectors.Vocab at 0x7f69ac1adad0>,
#  'htc': <gensim.models.keyedvectors.Vocab at 0x7f69ac1adbd0>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x7f69ac1adc10>,
#  'वज': <gensim.models.keyedvectors.Vocab at 0x7f69ac1adc90>,
#  'इनफ': <gensim.models.keyedvectors.Vocab at 0x7f69ac1add10>,
#  'नवस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1addd0>,
#  'वद': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ade10>,
#  'वजह': <gensim.models.keyedvectors.Vocab at 0x7f69ac1ade90>,
#  'अनद': <gensim.models.keyedvectors.Vocab at 0x7f69ac1adf10>,
#  'mad': <gensim.models.keyedvectors.Vocab at 0x7f69ac1adf90>,
#  'आम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1af050>,
#  'एह': <gensim.models.keyedvectors.Vocab at 0x7f69ac1af110>,
#  'पत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1af190>,
#  'ऐल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1af210>,
#  'चटख': <gensim.models.keyedvectors.Vocab at 0x7f69ac1af290>,
#  'ऐक': <gensim.models.keyedvectors.Vocab at 0x7f69ac1af310>,
#  'इलस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1af390>,
#  'खलत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1af410>,
#  'नफ': <gensim.models.keyedvectors.Vocab at 0x7f69ac1af490>,
#  'windows': <gensim.models.keyedvectors.Vocab at 0x7f69ac1af510>,
#  'phone': <gensim.models.keyedvectors.Vocab at 0x7f69ac1af590>,
#  'mobile': <gensim.models.keyedvectors.Vocab at 0x7f69ac1af610>,
#  'operating': <gensim.models.keyedvectors.Vocab at 0x7f69ac1af690>,
#  'system': <gensim.models.keyedvectors.Vocab at 0x7f69ac1af710>,
#  'घनत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1af790>,
#  'शकश': <gensim.models.keyedvectors.Vocab at 0x7f69ac1af810>,
#  'lumia': <gensim.models.keyedvectors.Vocab at 0x7f69ac1af890>,
#  'एमएसएम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1af910>,
#  'ऑनब': <gensim.models.keyedvectors.Vocab at 0x7f69ac1af990>,
#  'उसम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1afa10>,
#  'यरब': <gensim.models.keyedvectors.Vocab at 0x7f69ac1afa90>,
#  'आईप': <gensim.models.keyedvectors.Vocab at 0x7f69ac1afb50>,
#  'आइप': <gensim.models.keyedvectors.Vocab at 0x7f69ac1afb90>,
#  'डब': <gensim.models.keyedvectors.Vocab at 0x7f69ac1afc10>,
#  'android': <gensim.models.keyedvectors.Vocab at 0x7f69ac1afc90>,
#  'ice': <gensim.models.keyedvectors.Vocab at 0x7f69ac1afd10>,
#  'cream': <gensim.models.keyedvectors.Vocab at 0x7f69ac1afd90>,
#  'sandwich': <gensim.models.keyedvectors.Vocab at 0x7f69ac1afe10>,
#  'एमआइ': <gensim.models.keyedvectors.Vocab at 0x7f69ac1afe90>,
#  'आइ': <gensim.models.keyedvectors.Vocab at 0x7f69ac1aff10>,
#  'ओट': <gensim.models.keyedvectors.Vocab at 0x7f69ac1aff90>,
#  'एमआइय': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b1050>,
#  'नड': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b10d0>,
#  'मलय': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b1150>,
#  'मगर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b11d0>,
#  'उडस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b1250>,
#  'धब': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b12d0>,
#  'एसप': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b1390>,
#  'आयर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b1410>,
#  'एसआई': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b1490>,
#  'एलइड': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b1510>,
#  'रगन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b1590>,
#  'पश': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b1610>,
#  'लड': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b1690>,
#  'ऑक': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b1710>,
#  'गश': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b1790>,
#  'उज': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b1810>,
#  'उपस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b18d0>,
#  'लगन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b1950>,
#  'micromax': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b19d0>,
#  'canvas': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b1a50>,
#  'juice': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b1ad0>,
#  'एकब': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b1b50>,
#  'डट': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b1bd0>,
#  'एनएफस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b1c50>,
#  'ईल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b1cd0>,
#  'मसलन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b1d50>,
#  'एसएमएस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b1dd0>,
#  'एफएम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b1e50>,
#  'इकल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b1f10>,
#  'डस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b1f90>,
#  'एकम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b3050>,
#  'नव': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b30d0>,
#  'एसएम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b3150>,
#  'एमएस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b31d0>,
#  'चटक': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b3250>,
#  'दमद': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b32d0>,
#  'झल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b3350>,
#  'हट': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b33d0>,
#  'हरकत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b3450>,
#  'आख': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b34d0>,
#  'तल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b3550>,
#  'नम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b35d0>,
#  'आएग': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b3650>,
#  'खद': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b36d0>,
#  'जम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b3750>,
#  'ढल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b37d0>,
#  'रप': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b3850>,
#  'इजर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b3950>,
#  'एफएक': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b3990>,
#  'ऍसस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b3a10>,
#  'मनम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b3a90>,
#  'हक': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b3b90>,
#  'रहकर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b3b10>,
#  'उसन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b3c10>,
#  'हलक': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b3c90>,
#  'वप': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b3d10>,
#  'ईस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b3d90>,
#  'socs': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b3e10>,
#  'ओक': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b3e90>,
#  'धड': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b3f10>,
#  'ऍस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b3f90>,
#  'इनजस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b5050>,
#  'अम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b50d0>,
#  'तकल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b5150>,
#  'सकर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b51d0>,
#  'शब': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b5250>,
#  'डरस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b52d0>,
#  'खड': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b5350>,
#  'xl': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b53d0>,
#  'rs': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b5490>,
#  'ईन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b5550>,
#  'एज': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b55d0>,
#  'भत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b5650>,
#  'एडवर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b56d0>,
#  'इजम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b5790>,
#  'yu': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b57d0>,
#  'yuphoria': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b5850>,
#  'नज': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b58d0>,
#  'galaxy': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b5950>,
#  'उतर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b59d0>,
#  'curved': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b5a50>,
#  'edge': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b5ad0>,
#  'edges': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b5b50>,
#  'एहस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b5bd0>,
#  'note': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b5c50>,
#  'टरट': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b5cd0>,
#  'ओन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b5d50>,
#  'भल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b5dd0>,
#  'moto': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b5ed0>,
#  'connectivity': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b5e50>,
#  'lollipop': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b5f50>,
#  'भद': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b5fd0>,
#  'दम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b6090>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b6110>,
#  'रल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b6190>,
#  'जबरदस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b6210>,
#  'ui': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b6290>,
#  'xiaomi': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b6310>,
#  'miui': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b6390>,
#  'गलव': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b6410>,
#  'online': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b6490>,
#  'flash': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b6510>,
#  'sale': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b6590>,
#  'घट': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b6610>,
#  'कतई': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b6690>,
#  'quad': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b6710>,
#  'core': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b6790>,
#  'processor': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b6810>,
#  'hairline': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b6890>,
#  'brush': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b6910>,
#  'finish': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b6990>,
#  'mi': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b6a10>,
#  'तगड': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b6a90>,
#  'milli': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b6b10>,
#  'ampere': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b6b90>,
#  'hour': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b6c10>,
#  'औसतन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b6c90>,
#  'उतरत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b6d10>,
#  'सरल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b6d90>,
#  'ऍण': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b6e10>,
#  'उभ': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b6e90>,
#  'ठत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b6f10>,
#  'नत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b6f90>,
#  'soc': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b9050>,
#  'यव': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b90d0>,
#  'शटर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b9150>,
#  'गडबड': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b9250>,
#  'बजन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b91d0>,
#  'बज': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b92d0>,
#  'नजनक': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b9350>,
#  'ज़ल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b9450>,
#  'टरप': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b93d0>,
#  'यध': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b94d0>,
#  'ठहर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b9590>,
#  'तत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b95d0>,
#  'हरण': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b96d0>,
#  'पकड़न': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b9710>,
#  'ओग': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b9750>,
#  'समग': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b97d0>,
#  'सख': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b9850>,
#  'कड़': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b98d0>,
#  'mpऔर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b99d0>,
#  'बदलन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b9a50>,
#  'हटकर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b9ad0>,
#  'nd': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b9b50>,
#  'gen': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b9bd0>,
#  'एलट': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b9c50>,
#  'चकर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b9cd0>,
#  'कतवर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b9d50>,
#  'आउटड': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b9dd0>,
#  'लय': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b9e50>,
#  'सन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b9f10>,
#  'हज़': <gensim.models.keyedvectors.Vocab at 0x7f69ac1b9f90>,
#  'कमज़': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bb090>,
#  'ईफ़': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bb110>,
#  'आरएफ': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bb150>,
#  'lg': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bb210>,
#  'हफ': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bb290>,
#  'अपड': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bb310>,
#  'असफलत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bb390>,
#  'दरत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bb410>,
#  'lte': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bb4d0>,
#  'हथ': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bb510>,
#  'परन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bb590>,
#  'तरण': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bb610>,
#  'ठन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bb750>,
#  'थक': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bb6d0>,
#  'दनश': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bb7d0>,
#  'पष': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bb850>,
#  'अवश': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bb8d0>,
#  'परव': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bb950>,
#  'यय': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bb9d0>,
#  'आनन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bba90>,
#  'उल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bbad0>,
#  'खल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bbb50>,
#  'उपर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bbbd0>,
#  'नजद': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bbc50>,
#  'आइक': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bbd10>,
#  'ववर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bbdd0>,
#  'रब': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bbe10>,
#  'दश': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bbe90>,
#  'भड': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bbf10>,
#  'रबरय': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bbf90>,
#  'पकडन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bc050>,
#  'वरव': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bc0d0>,
#  'sgx': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bc150>,
#  'mt': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bc1d0>,
#  'बख': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bc250>,
#  'यट': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bc2d0>,
#  'अगल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bc350>,
#  'खक': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bc3d0>,
#  'चरल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bc4d0>,
#  'इयरफ': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bc450>,
#  'चमकत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bc550>,
#  'एसआइ': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bc650>,
#  'सरव': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bc5d0>,
#  'आउटफ': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bc6d0>,
#  'खकर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bc750>,
#  'दग': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bc7d0>,
#  'ऍप': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bc850>,
#  'कहल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bc8d0>,
#  'छड': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bc950>,
#  'बग': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bc9d0>,
#  'टत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bca50>,
#  'ओज': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bcad0>,
#  'कग': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bcb50>,
#  'गरम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bcbd0>,
#  'ऍक': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bcc50>,
#  'रमश': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bccd0>,
#  'धक': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bcd50>,
#  'एडव': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bcdd0>,
#  'बनन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bce50>,
#  'मरस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bced0>,
#  'रर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bcf50>,
#  'परद': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bcfd0>,
#  'डलन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1be110>,
#  'लकम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1be190>,
#  'पद': <gensim.models.keyedvectors.Vocab at 0x7f69ac1be050>,
#  'समझद': <gensim.models.keyedvectors.Vocab at 0x7f69ac1be210>,
#  'हनत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1be290>,
#  'उनस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1be310>,
#  'पहच': <gensim.models.keyedvectors.Vocab at 0x7f69ac1be390>,
#  'गलतफहम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1be410>,
#  'हड': <gensim.models.keyedvectors.Vocab at 0x7f69ac1be490>,
#  'जबरन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1be510>,
#  'फद': <gensim.models.keyedvectors.Vocab at 0x7f69ac1be590>,
#  'अरशद': <gensim.models.keyedvectors.Vocab at 0x7f69ac1be650>,
#  'बच': <gensim.models.keyedvectors.Vocab at 0x7f69ac1be6d0>,
#  'लहज': <gensim.models.keyedvectors.Vocab at 0x7f69ac1be750>,
#  'भगन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1be7d0>,
#  'जग': <gensim.models.keyedvectors.Vocab at 0x7f69ac1be850>,
#  'सलम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1be8d0>,
#  'उर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1be950>,
#  'रबदल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1be9d0>,
#  'पप': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bea50>,
#  'जमर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bead0>,
#  'शहर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1beb90>,
#  'ओवर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bec10>,
#  'जट': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bec90>,
#  'सरप': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bed10>,
#  'नप': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bed90>,
#  'वनल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bee10>,
#  'इनर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bee90>,
#  'दत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bef10>,
#  'आगमन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1bef90>,
#  'पटकथ': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c1050>,
#  'बनत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c10d0>,
#  'डरन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c1150>,
#  'तज': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c11d0>,
#  'नजक': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c1250>,
#  'वसन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c12d0>,
#  'मसल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c1350>,
#  'आमत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c1410>,
#  'कबस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c1510>,
#  'परह': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c1690>,
#  'आयरनम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c1590>,
#  'टसल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c16d0>,
#  'इधर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c1750>,
#  'ईश': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c1810>,
#  'आकस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c1890>,
#  'परतद': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c18d0>,
#  'रच': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c1950>,
#  'जज': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c19d0>,
#  'वत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c1a90>,
#  'ममत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c1b10>,
#  'समल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c1b90>,
#  'भट': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c1a50>,
#  'शम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c1c10>,
#  'ढर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c1c90>,
#  'कढ': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c1d90>,
#  'घड': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c1e10>,
#  'दस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c1ed0>,
#  'भरद': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c1f90>,
#  'चमत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c1d10>,
#  'धत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c1f10>,
#  'हण': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c3250>,
#  'जहद': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c3050>,
#  'झन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c30d0>,
#  'सद': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c3150>,
#  'मव': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c31d0>,
#  'चय': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c32d0>,
#  'दशक': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c3350>,
#  'यवश': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c3410>,
#  'ठभ': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c34d0>,
#  'कलकर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c3450>,
#  'नसन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c3550>,
#  'मवर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c35d0>,
#  'ओह': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c3650>,
#  'पड़': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c36d0>,
#  'ओवरऑल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c3750>,
#  'धर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c3810>,
#  'मप': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c3890>,
#  'रचल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c3910>,
#  'णन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c3990>,
#  'सतह': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c3a10>,
#  'तह': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c3a90>,
#  'हन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c3b10>,
#  'कठम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c3c50>,
#  'सफल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c3c90>,
#  'मकत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c3cd0>,
#  'शल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c3d50>,
#  'रमज': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c3dd0>,
#  'आहत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c3e50>,
#  'षय': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c3ed0>,
#  'परवर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c3f90>,
#  'शरद': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c3fd0>,
#  'बनर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c5090>,
#  'गढ': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c5110>,
#  'रजत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c5190>,
#  'यशर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c5210>,
#  'सहय': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c5290>,
#  'जप': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c53d0>,
#  'अज': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c5350>,
#  'यसओवर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c54d0>,
#  'रजन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c5450>,
#  'चरत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c5550>,
#  'भटक': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c55d0>,
#  'उभर': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c5650>,
#  'मध': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c56d0>,
#  'औचकपन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c5750>,
#  'खरत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c57d0>,
#  'यवत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c5850>,
#  'गलप': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c58d0>,
#  'वई': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c5950>,
#  'अफस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c59d0>,
#  'जस': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c5a50>,
#  'यचक': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c5ad0>,
#  'रकल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c5b50>,
#  'ड़त': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c5c10>,
#  'उपन': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c5d50>,
#  'जख': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c5c50>,
#  'इटल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c5cd0>,
#  'टरवल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c5dd0>,
#  'रफ': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c5e50>,
#  'झलकत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c5ed0>,
#  'जसप': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c5f90>,
#  'ऋष': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c5fd0>,
#  'चड': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c7090>,
#  'उचट': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c7150>,
#  'कटव': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c72d0>,
#  'अनफ': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c71d0>,
#  'नकल': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c7250>,
#  'नवद': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c7310>,
#  'एनएच': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c7390>,
#  'अपशब': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c7410>,
#  'सहम': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c74d0>,
#  'अनगढ': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c75d0>,
#  'रमण': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c7690>,
#  'यकप': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c7610>,
#  'अनज': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c7790>,
#  'कठ': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c7590>,
#  'जत': <gensim.models.keyedvectors.Vocab at 0x7f69ac1c7910>,
#  ...}

# %%
hindi_word2vec_model.similar_by_word("कलकर")
# Out:
# /home/venktesh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `similar_by_word` (Method will be removed in 4.0.0, use self.wv.similar_by_word() instead).
#   """Entry point for launching an IPython kernel.
# [('कठम', 0.9989670515060425),
#  ('सजत', 0.9988631010055542),
#  ('ठभ', 0.9987788200378418),
#  ('अनग', 0.9986453652381897),
#  ('हड', 0.9986263513565063),
#  ('असरह', 0.9986004829406738),
#  ('तलपड', 0.9985721111297607),
#  ('रतप', 0.9985638856887817),
#  ('नर', 0.9985034465789795),
#  ('बदम', 0.9984847903251648)]
